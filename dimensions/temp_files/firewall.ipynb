sIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiX2NzcmZ0XyI6ICIwZDU0MTcxN2IwOTNmYTE0ZjE3OWFlNzY4MWZiNmU3MDljMTE5NjI5IiwgImF1dGhfbWV0aG9kIjogImRpbWVuc2lvbnMifV0',
  'Expires': '0',
  'Operations': 'sticky=zTs8qKkvxcKgHOPbEXlzPzGcuL2944F7oWN48uR5',
  'Pragma': 'no-cache',
  'Referer': 'https://app.dimensions.ai/discover/publication',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
  'X-CSRF-Token': '0d541717b093fa14f179ae7681fb6e709c119629',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

# response = requests.request("GET", url, headers=headers, data=payload)

# print(response.status_code)
url_params = "&or_facet_publication_type=article&and_facet_year=2024"
url_base = "https://app.dimensions.ai"

# %%
from datetime import datetime
url_params = "&or_facet_publication_type=article&and_facet_year=2024"
url_base = "https://app.dimensions.ai"
def pipe(url,request_number):
    try:
        response = requests.request("GET", url, headers=headers, data=payload)
        data = response.json()
        url_np = data['navigation']['results_json']
        url = url_base+url_np+url_params
        print('numer:',request_number,' ->>code: ',response.status_code,' ->>time: ',datetime.now().strftime('%H:%M:%S'),'->>np: ',url_np)
        return pipe(url,request_number+1)
    except Exception as err:
        print('exception: ',err,' ->>time:',datetime.now().strftime('%H:%M:%S'))

# %%
pipe(url)
# Out:
# request number: 0  ->> status code: 200  ->>time: 21:33:57
# request number: 0  ->> status code: 200  ->>time: 21:33:59
# request number: 0  ->> status code: 200  ->>time: 21:34:00
# request number: 0  ->> status code: 200  ->>time: 21:34:02
# request number: 0  ->> status code: 200  ->>time: 21:34:04
# request number: 0  ->> status code: 200  ->>time: 21:34:05
# request number: 0  ->> status code: 200  ->>time: 21:34:07
# request number: 0  ->> status code: 200  ->>time: 21:34:09
# request number: 0  ->> status code: 200  ->>time: 21:34:10
# request number: 0  ->> status code: 200  ->>time: 21:34:12
# request number: 0  ->> status code: 200  ->>time: 21:34:14
# request number: 0  ->> status code: 200  ->>time: 21:34:16
# request number: 0  ->> status code: 200  ->>time: 21:34:18
# ...

# %%
import requests
import json

url = "https://app.dimensions.ai/discover/publication/results.json?or_facet_publication_type=article&or_facet_year=2024"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'no-cache, no-store, must-revalidate',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Cookie': 'aws-waf-token=7ac190f2-7850-4639-b888-1b60ef0a6171:EQoAYDx1DwoNAAAA:qqtIXmPiavH9zfcwzFwz5D2B/51cPnLI+iFeRXbo9AUwe1gAEa0Dkc01EcanzGc+ipQ4itvkUQIPtrLTQ1ZOf7Oihjy0W64E9ft47Max4yfyd0UpaGU5+2YFDOp5qSo8eLJQP7bGldeGaIsOQ/CQm+8/58IYQ91NkyBNJdCOVwdShBT3D7PqQGNYXEPnitSiCGt7eQjY6q+X7vHhiH1vsh8pzboQvgH43h3zrUPvMHdA96op7EG+AXzR; OptanonAlertBoxClosed=2024-02-08T16:44:46.815Z; intercom-device-id-ilx5k1fm=99edab8a-a6ab-47e3-bc44-070b8257d181; _gcl_au=1.1.1416844146.1707413904; _gid=GA1.2.1590107742.1707413905; _ga_WT8T40BY8E=GS1.1.1707413903.1.0.1707413911.52.0.0; _ga_CHDNWH4YDX=GS1.1.1707413904.1.0.1707413911.0.0.0; _ga=GA1.1.1020259313.1707410685; uber_auth_tkt=e7ac6061ced0dc30ddcb0775a8b5955edc4ffcf1b4623e2af114a0291bc6cc021a18e8bc451698a36a37f83f7b5c61d36792f7efda886fce5febc332f6b538fb65c517ceYWFjYzk4MThAZ21haWwuY29t!A7f47b3516942805735b71d30590c7a!userid_type:b64unicode; uber_auth_tkt=e7ac6061ced0dc30ddcb0775a8b5955edc4ffcf1b4623e2af114a0291bc6cc021a18e8bc451698a36a37f83f7b5c61d36792f7efda886fce5febc332f6b538fb65c517ceYWFjYzk4MThAZ21haWwuY29t!A7f47b3516942805735b71d30590c7a!userid_type:b64unicode; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Feb+08+2024+21%3A37%3A10+GMT%2B0330+(Iran+Standard+Time)&version=202401.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=69767275-7067-4802-94fe-5284274a777b&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1&AwaitingReconsent=false&geolocation=GB%3BENG; intercom-session-ilx5k1fm=S2ZwZmRoSi85TlhycURPajg2Vi9aY3lFVFZTRDNmZFh2aEF0bi8yd0hVS1JTbzRXSjF6U1A5TVRIMGRPdHNHUi0tQ2NCTTR2d2o0NElFam9zMXhGTHoyQT09--a99ad6efc4abb2302f9734c8f71f385638e29a3f; _ga_KH7CX71Y5X=GS1.1.1707410685.1.1.1707415636.0.0.0; session=; session=JcEs4c9Saz7mv-nOdRVd8uhhFt3OZ5B4vFWenaGmTAPm5qH4JOxe5ysP4T8mbPLu6P-4zLQ5qUsbGW5XKT17rVsxNzA3NDE1ODUxLCAxNzA3NDEwNjc2LjQ1MjI3NDMsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiX2NzcmZ0XyI6ICIwZDU0MTcxN2IwOTNmYTE0ZjE3OWFlNzY4MWZiNmU3MDljMTE5NjI5IiwgImF1dGhfbWV0aG9kIjogImRpbWVuc2lvbnMifV0',
  'Expires': '0',
  'Operations': 'sticky=Jc7nqtoYdodAocAe55X3belxcM7QQp4gOjYbpfi6',
  'Pragma': 'no-cache',
  'Referer': 'https://app.dimensions.ai/discover/publication?or_facet_publication_type=article&or_facet_year=2024',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
  'X-CSRF-Token': '2b8fbc333b0a6eeee380e3ee05bcbe7810f44843',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"subsets_info": [], "count": 489401, "docs": [{"title": "Joseph Needham\u2019s \u2018Motivations for Participation\u2019 and \u2018Major Roles\u2019 in the International Scientific Commission on Bacterial Warfare during the Korean War", "affiliations_json": "[{\"first_name\": \"Taewoo\", \"last_name\": \"Kim\", \"raw_affiliation\": [\"Associate Professor, Department of Korean Studies, Hankuk University of Foreign Studies.\"], \"first_name_original\": \"\", \"last_name_original\": \"\", \"raw_affiliation_original\": [], \"initials\": \"\", \"corresponding\": \"\", \"orcid\": null, \"current_organization_id\": \"grid.440932.8\", \"researcher_id\": \"ur.015475752763.80\", \"affiliations\": [{\"id\": \"grid.440932.8\", \"name\": \"Hankuk University of Foreign Studies\", \"city\": \"Seoul\", \"city_id\": 1835848, \"country\": \"South Korea\", \"country_code\": \"KR\", \"state\": null, \"state_code\": null, \"raw_affiliation\": \"Associate Professor, Department of Korean Studies, Hankuk U
# ...

# %%
pipe(url) # new login
# Out:
# exception:  HTTPSConnectionPool(host='app.dimensions.ai', port=443): Max retries exceeded with url: /discover/publication/results.json?or_facet_publication_type=article&or_facet_year=2024 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))  ->>time: 21:42:02

# %%
import requests
import json

url = "https://app.dimensions.ai/discover/publication/results.json?np=ce2tUMu8bMHGFT27C4YL-cozPXqyT5fWEsgqenYGdi7gl_5GZf_m-0Aj&or_facet_year=2024&or_facet_publication_type=article"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 
sIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiX2NzcmZ0XyI6ICIwZDU0MTcxN2IwOTNmYTE0ZjE3OWFlNzY4MWZiNmU3MDljMTE5NjI5IiwgImF1dGhfbWV0aG9kIjogImRpbWVuc2lvbnMifV0',
  'Expires': '0',
  'Operations': 'sticky=EDeXZFl6UQjJ3HJ2H61rzcSvPXiYzuBpGeEzXweK',
  'Pragma': 'no-cache',
  'Referer': 'https://app.dimensions.ai/discover/publication?or_facet_year=2024&or_facet_publication_type=article',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
  'X-CSRF-Token': '85aadf5d1e40bd37644a18ef9613e57312b91de5',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"subsets_info": [], "count": 489401, "docs": [{"title": "TOMATO GARANTIK F1 FOR \u00abFITOPIRAMIDA\u00bb TECHNOLOGY", "issn": ["2658-4832", "26584832"], "source_title_id": "jour.1385344", "journal_title": "News of FSVC", "language": "en", "abstract_language": "en", "publisher_source": "FSBSI All-Russian Scientfic Research Institute of Vegetable Breeding and Seed Production", "publisher_place": "Moscow, VNISSOK, Odintsovo District, Russia", "publisher": "FSBSI All-Russian Scientfic Research Institute of Vegetable Breeding and Seed Production", "pub_class": "Article", "citation_string_year": 2024, "created_in_dimensions": "2023-12-25T21:57:20Z", "doi": "10.18619/2658-4832-2023-4-22-27", "id": "pub.1167319428", "online_pub_date": "2024-12-23", "print_pub_date": "2024-12-22", "pub_date": "2024-12-22", "pub_year": 2024, "times_cited": 0, "score": 1.0, "affiliations_details": [], "authors_full": [], "source_title": "News of FSVC", "pub_class_id": "article", "openurl": null, "orcid": {"api
# ...

# %%
pipe(url,0) # new account
# Out:
# numer: 0  ->>code:  200  ->>time:  21:48:46 ->>np:  /discover/publication/results.json?np=5xOZ1U1WeJDN1x0i7Wo2NIE-3UYdAau16aCPO7TXL7RyxR7mrmoe5FLi
# numer: 0  ->>code:  200  ->>time:  21:48:48 ->>np:  /discover/publication/results.json?np=XAQ1a3l5LD5oxhbpjhbYVd5vRBhfLjNClKIpkjThW0I7hhJ6Im0FQroh
# numer: 0  ->>code:  200  ->>time:  21:48:50 ->>np:  /discover/publication/results.json?np=fp1TySfrHxZAnBgpr2Y5jBlqv3sPDraA7un9fDV4Jsc6S7kmQNcBYQM6
# numer: 0  ->>code:  200  ->>time:  21:48:51 ->>np:  /discover/publication/results.json?np=Zze9FrAn3GQ2erX8BPEK82Rz7regRubV8p-YFEYrXiVAa9t6Ff5vlqSK
# numer: 0  ->>code:  200  ->>time:  21:48:53 ->>np:  /discover/publication/results.json?np=t-Nndihvzl5xixjmHfb8qeA9mq5TFlzH7XagtbB4d6yHCniTKgbUhz7e
# numer: 0  ->>code:  200  ->>time:  21:48:55 ->>np:  /discover/publication/results.json?np=pu3DIn2hGeBr788ahcZP_8HZv3e6aFhGGS8I4jPVe8Lvt2sa3LnncBwjyw%3D%3D
# ...

# %%
import requests
import json

url = "https://app.dimensions.ai/discover/publication/results.json?np=ce2tUMu8bMHGFT27C4YL-cozPXqyT5fWEsgqenYGdi7gl_5GZf_m-0Aj&or_facet_year=2024&or_facet_publication_type=article"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'no-cache, no-store, must-revalidate',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  '

  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
  'X-CSRF-Token': '85aadf5d1e40bd37644a18ef9613e57312b91de5',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"subsets_info": [], "count": 489401, "docs": [{"title": "TOMATO GARANTIK F1 FOR \u00abFITOPIRAMIDA\u00bb TECHNOLOGY", "issn": ["2658-4832", "26584832"], "source_title_id": "jour.1385344", "journal_title": "News of FSVC", "language": "en", "abstract_language": "en", "publisher_source": "FSBSI All-Russian Scientfic Research Institute of Vegetable Breeding and Seed Production", "publisher_place": "Moscow, VNISSOK, Odintsovo District, Russia", "publisher": "FSBSI All-Russian Scientfic Research Institute of Vegetable Breeding and Seed Production", "pub_class": "Article", "citation_string_year": 2024, "created_in_dimensions": "2023-12-25T21:57:20Z", "doi": "10.18619/2658-4832-2023-4-22-27", "id": "pub.1167319428", "online_pub_date": "2024-12-23", "print_pub_date": "2024-12-22", "pub_date": "2024-12-22", "pub_year": 2024, "times_cited": 0, "score": 1.0, "affiliations_details": [], "authors_full": [], "source_title": "News of FSVC", "pub_class_id": "article", "openurl": null, "orcid": {"api
# ...

# %%
pipe(url,0) # temp email
# Out:
# numer: 0  ->>code:  200  ->>time:  21:59:42 ->>np:  /discover/publication/results.json?np=-R_B2Kqb-rYwZmB2VvV0dSc68FSulQnP867bE7zz0TpnBnNGIzdpBdcB
# numer: 1  ->>code:  200  ->>time:  21:59:44 ->>np:  /discover/publication/results.json?np=9PpORWoOCAyK21st2TTfv9iFPoxWOCFSI5m9nwv-nU9oxRA1hSeXWz_Z
# numer: 2  ->>code:  200  ->>time:  21:59:45 ->>np:  /discover/publication/results.json?np=Y3t8DssYjL0KsuD9aixidP3ukClT3zsRqMDzakSVirMaWSl02xbWyrJn
# numer: 3  ->>code:  200  ->>time:  21:59:47 ->>np:  /discover/publication/results.json?np=_09wMowQgg5d4dBmUxglYfLbucZy-5Y7_QFHKCPXsaVh96evPVjXXKUC
# numer: 4  ->>code:  200  ->>time:  21:59:48 ->>np:  /discover/publication/results.json?np=7V3_CwXvpsux2oySkUXp0aQlRlEOYtyMslQkIilJvRnjR0GrULcMhnjV
# numer: 5  ->>code:  200  ->>time:  21:59:50 ->>np:  /discover/publication/results.json?np=qParFf4MU5OTzASfUi1MZHgGDTn4h50XGVIY9gY-oHQBztYOjjhjn7u4AQ%3D%3D
# ...

# %%
import requests
import json

url = "https://app.dimensions.ai/discover/publication/results.json?np=SQVKbQrV1nCZqLUUocfegl_MoQ-OdbP8vHQ5uBGYyWNBxgXWlVQUpa8P&"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'no-cache, no-store, must-revalidate',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Cookie': 'OptanonAlertBoxClosed=2024-02-08T16:44:46.815Z; intercom-device-id-ilx5k1fm=99edab8a-a6ab-47e3-bc44-070b8257d181; _gcl_au=1.1.1416844146.1707413904; _gid=GA1.2.1590107742.1707413905; _ga_WT8T40BY8E=GS1.1.1707413903.1.0.1707413911.52.0.0; _ga_CHDNWH4YDX=GS1.1.1707413904.1.0.1707413911.0.0.0; _ga=GA1.1.1020259313.1707410685; aws-waf-token=7ac190f2-7850-4

  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

# %%
pipe(url,0)
# Out:
# numer: 0  ->>code:  200  ->>time:  22:08:20 ->>np:  /discover/publication/results.json?np=Cr_WZBFA8N6TViXXRajJBFVD8upVHVGTNKYSM_VmkhtzZ-G2_-QoajJs
# numer: 1  ->>code:  200  ->>time:  22:08:21 ->>np:  /discover/publication/results.json?np=K3LjUZJjakyLrzkopg-_TjWv1xYw3op457L7y7hjQ1AaOTl4utdM6ovD
# numer: 2  ->>code:  200  ->>time:  22:08:23 ->>np:  /discover/publication/results.json?np=AJJtjDkQB-oPOz8OD12jSQgZx03XyIUsacm39SWO0wMWRVl5nlpmEDFo
# numer: 3  ->>code:  200  ->>time:  22:08:24 ->>np:  /discover/publication/results.json?np=u7UdUwnm2-osbGWBaLw2MRsLy6ZhlRVz_LY0tFmKr5VSow1qgrfcQ5vI
# exception:  HTTPSConnectionPool(host='app.dimensions.ai', port=443): Max retries exceeded with url: /discover/publication/results.json?np=u7UdUwnm2-osbGWBaLw2MRsLy6ZhlRVz_LY0tFmKr5VSow1qgrfcQ5vI&or_facet_publication_type=article&and_facet_year=2024 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))  ->>time: 22:08:29

# %%
import requests
import json

url = "https://app.dimensions.ai/discover/publication/results.json?np=Bf4s4Q_8LMAHbKru9-y6jT8GODDjThFepZoUjCJi6zo4-079MCoFVMhL&or_facet_year=2024&or_facet_publication_type=article"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'no-cache, no-store, must-revalidate',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Cookie': 'uber_auth_tkt=c38f7baf7a3abe131c16334f8debdfd196994ec7bea3773f0b7edb0b12f9c2f1aaa14189313b5561d0fd438a4d05685773e3f3a8c1c1f376b42ed1b6e0dd34e365c527c3eW9wYWoyMjMxNEBvcHJldm9sdC5jb20%3D!A50519a8823992f4625f21d9e23d194!userid_type:b64unicode; uber_auth_tkt=c38f7baf7a3abe131c16334f8debdfd196994ec7bea3773f0b7edb0b12f9c2f1aaa14189313b5561d0fd438a4d05685773e3f3a8c1c1f376b42ed1b6e0dd34e365c527c3eW9wYWoyMjMxNEBvcHJldm9sdC5jb20%3D!A50519a8823992f4625f21d9e23d194!userid_type:b64unicode; OptanonAlertBoxClosed=2024-02-08T19:13:28.249Z; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Feb+08+2024+22%3A43%3A50+GMT%2B0330+(Iran+Standard+Time)&version=202401.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=67f585d3-6138-4244-a7c4-a48daea5e005&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0&geolocation=NL%3BUT&AwaitingReconsent=false; session=15Wam0V30IJfx-vEJwgkEaYS3LdxQjOZ2A3xAinLPvP8EmLOtqVmjaAWLpn9HPmGDlMx5dlkmBP3qptuJQT8-FsxNzA3NDE5NjYwLCAxNzA3NDE5NTg3LjQzMjgyMTMsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiYXV0aF9tZXRob2QiOiAiZGltZW5zaW9ucyIsICJfY3NyZnRfIjogImVlZWRmOTNhYmIwMjVjYTE4M2I5MmYxMjhjNTUxYmQwMDg5NWRkYzUifV0; session=DDBI4vqitDb7T_RvHJ2NFfF8eAjmDZuEZOhyiBeDcxt31Kq96H1B_IVuC_pCpKcGUTcOsiojVNm2-XJHNrypW1sxNzA3NDE5NzA1LCAxNzA3NDE5NTg3LjQzMjgyMTMsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiYXV0aF9tZXRob2QiOiAiZGltZW5zaW9ucyIsICJfY3NyZnRfIjogImVlZWRmOTNhYmIwMjVjYTE4M2I5MmYxMjhjNTUxYmQwMDg5NWRkYzUifV0',
  'Expires': '0',
  'Operations': 'sticky=GZiv6GZgVY1uEKpKX6GX7gMuNXJZSc8syfuYUZTQ',
  'Pragma': 'no-cache',
  'Referer': 'https://app.dimensions.ai/discover/publication?or_facet_year=2024&or_facet_publication_type=article',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0',
  'X-CSRF-Token': 'eeedf93abb025ca183b92f128c551bd00895ddc5',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Microsoft Edge";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

# %%
pipe(url,0) # new ip(parsas vpn)
# Out:
# numer: 0  ->>code:  200  ->>time:  22:48:00 ->>np:  /discover/publication/results.json?np=_q1sfUCn30G5nkpwT8mThxW_kUqTmxEnAc_n6noEcdZOo-5ofo1LHJ9j
# numer: 1  ->>code:  200  ->>time:  22:48:01 ->>np:  /discover/publication/results.json?np=KM8_qbVVjz2VYJq09DZtzhNtcLqGLKwOXVsX2O6uSSwdnuEDdNtWrquK
# exception:  HTTPSConnectionPool(host='app.dimensions.ai', port=443): Max retries exceeded with url: /discover/publication/results.json?np=KM8_qbVVjz2VYJq09DZtzhNtcLqGLKwOXVsX2O6uSSwdnuEDdNtWrquK&or_facet_publication_type=article&and_facet_year=2024 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))  ->>time: 22:48:07

# %%
import requests
import json

url = "https://app.dimensions.ai/discover/publication/results.json?np=Bf4s4Q_8LMAHbKru9-y6jT8GODDjThFepZoUjCJi6zo4-079MCoFVMhL&or_facet_year=2024&or_facet_publication_type=article"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'no-cache, no-store, must-revalidate',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Cookie': 'uber_auth_tkt=c38f7baf7a3abe131c16334f8debdfd196994ec7bea3773f0b7edb0b12f9c2f1aaa14189313b5561d0fd438a4d05685773e3f3a8c1c1f376b42ed1b6e0dd34e365c527c3eW9wYWoyMjMxNEBvcHJldm9sdC5jb20%3D!A50519a8823992f4625f21d9e23d194!userid_type:b64unicode; uber_auth_tkt=c38f7baf7a3abe131c16334f8debdfd196994ec7bea3773f0b7edb0b12f9c2f1aaa14189313b5561d0fd438a4d05685773e3f3a8c1c1f376b42ed1b6e0dd34e365c527c3eW9wYWoyMjMxNEBvcHJldm9sdC5jb20%3D!A50519a8823992f4625f21d9e23d194!userid_type:b64unicode; OptanonAlertBoxClosed=2024-02-08T19:13:28.249Z; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Feb+08+2024+22%3A43%3A50+GMT%2B0330+(Iran+Standard+Time)&version=202401.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=67f585d3-6138-4244-a7c4-a48daea5e005&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0&geolocation=NL%3BUT&AwaitingReconsent=false; session=15Wam0V30IJfx-vEJwgkEaYS3LdxQjOZ2A3xAinLPvP8EmLOtqVmjaAWLpn9HPmGDlMx5dlkmBP3qptuJQT8-FsxNzA3NDE5NjYwLCAxNzA3NDE5NTg3LjQzMjgyMTMsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiYXV0aF9tZXRob2QiOiAiZGltZW5zaW9ucyIsICJfY3NyZnRfIjogImVlZWRmOTNhYmIwMjVjYTE4M2I5MmYxMjhjNTUxYmQwMDg5NWRkYzUifV0; session=DDBI4vqitDb7T_RvHJ2NFfF8eAjmDZuEZOhyiBeDcxt31Kq96H1B_IVuC_pCpKcGUTcOsiojVNm2-XJHNrypW1sxNzA3NDE5NzA1LCAxNzA3NDE5NTg3LjQzMjgyMTMsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiYXV0aF9tZXRob2QiOiAiZGltZW5zaW9ucyIsICJfY3NyZnRfIjogImVlZWRmOTNhYmIwMjVjYTE4M2I5MmYxMjhjNTUxYmQwMDg5NWRkYzUifV0',
  'Expires': '0',
  'Operations': 'sticky=GZiv6GZgVY1uEKpKX6GX7gMuNXJZSc8syfuYUZTQ',
  'Pragma': 'no-cache',
  'Referer': 'https://app.dimensions.ai/discover/publication?or_facet_year=2024&or_facet_publication_type=article',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) afari/121.0.0.0 Safari/537.36 Edg/121.0.0.0',
  'X-CSRF-Token': 'eeedf93abb025ca183b92f128c551bd00895ddc5',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Microsoft Edge";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

# %%
pipe(url,0) # new user agent
# Out:
# numer: 0  ->>code:  200  ->>time:  22:57:11 ->>np:  /discover/publication/results.json?np=rLr9pSV71tqRA3FtwriUxVwyQ2YsJctcHKFhjXTYL0u3syw6iXN2egBZ
# numer: 1  ->>code:  200  ->>time:  22:57:14 ->>np:  /discover/publication/results.json?np=hnFy15fQkcL6JFDz0Ewi8zOe-WAPH5JDWNzvK5cUPuoNaXD6lTB4480F
# numer: 2  ->>code:  200  ->>time:  22:57:15 ->>np:  /discover/publication/results.json?np=uXCnUUKKrqovqTfGgsrvpw_PynFZmx6eD7J2eeBL02sPW5lagrm2Vy9q
# numer: 3  ->>code:  200  ->>time:  22:57:18 ->>np:  /discover/publication/results.json?np=Y63sUs-XMV2j8q4QSb2MZkd5ZdISwR7rkjtZhpxqO7KM3KythaoQMSEK
# numer: 4  ->>code:  200  ->>time:  22:57:22 ->>np:  /discover/publication/results.json?np=EV29ivn6KoR6ausjb-C0UtXKhZtQNN7j3B-KR1gdemcFAFM82BFGK7HD
# numer: 5  ->>code:  200  ->>time:  22:57:25 ->>np:  /discover/publication/results.json?np=kEkHrE8vXENhyt1ZsJwYWvOhi0vltGnEdUP69q6ERzdkYOAT4QYl1x7X
# ...

# %%
pipe(url,0) # without vpn
# Out:
# numer: 0  ->>code:  200  ->>time:  22:57:58 ->>np:  /discover/publication/results.json?np=Mi3AOr-Ihr2XcFRdF6sbNiswfWcq_1re5K00lVigj1tfI4vpaAuammzO
# numer: 1  ->>code:  200  ->>time:  22:57:59 ->>np:  /discover/publication/results.json?np=6so4VkUdlj5sQUgv_4Q3_N4g0Zxg5HvtUthr7VwxSfIkhthHPsiEz4ry
# numer: 2  ->>code:  200  ->>time:  22:58:00 ->>np:  /discover/publication/results.json?np=2pcEQuM-8xxmf7BLnMSA-Agi7ZuHDC51_I2qoR6n6tWhyF-skzQS1n0J
# numer: 3  ->>code:  200  ->>time:  22:58:02 ->>np:  /discover/publication/results.json?np=b9gLZrI5i1busZYik7GcLokdqiiaTEWsdlO-fiwnaPYE16l35fA-Eiji
# numer: 4  ->>code:  200  ->>time:  22:58:03 ->>np:  /discover/publication/results.json?np=TyXSOyYhxTVf0F3Z7xC7lBqY5wvfHvuucunkcUl1YSC6pic6rj7JvKEb
# numer: 5  ->>code:  200  ->>time:  22:58:04 ->>np:  /discover/publication/results.json?np=dv8K_HAjRG8PY_SklKh1_vtIIFVPqaYRtFULjgMojjNWl5cAb4mJ38aC
# ...
