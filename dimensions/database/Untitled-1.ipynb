# %%
import requests
import json
import pandas as pd 
url = "https://app.dimensions.ai/viz/data/publication/source_title/aggregated-citations.json?or_facet_publication_type=article&viz-st:aggr=mean"

payload = {}
headers = {
  'Accept': 'application/json',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'no-cache, no-store, must-revalidate',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Cookie': 'intercom-device-id-ilx5k1fm=99edab8a-a6ab-47e3-bc44-070b8257d181; _gcl_au=1.1.1416844146.1707413904; _ga=GA1.1.1098850320.1707419421; OptanonAlertBoxClosed=2024-02-08T19:10:23.090Z; _ga_Y26MGCNDNL=GS1.1.1707497562.1.1.1707498194.0.0.0; intercom-session-ilx5k1fm=RGZER09rMmpFMjlna0RjcWlJcmNmaXI0QnA4Qk9XcVAzOGFZbFRFZ1EwdndvSzR6bkFDM0lxUHdOeEFOVkVGdC0tQ1lRL1UyeVVvRW1mQmtVSnp4RW9oZz09--fa79964d35b160856576c10869311a1071c30b1b; aws-waf-token=fe37ef2f-f227-47e9-b02c-28e13cfdd591:EQoAdtiTsf4CAAAA:qwMeE8QyXyH4ZL8ea0MQeGFNfeM1TDJBq6Uujhm85rjRxqm2HebsPexjRt6kx+MZujWtsSRu7FPLhldC1BVtt3bS2ZODu8xZIsHdwJsm4EDth6XVMxpBruDfTAxKk7yl+USZndF8ivMEPTG0F0Xr/JaklrCIxJzEVpgcLwjMMGarTQIQ7tWD3Vnnwh4ns9koFki3tIeZxTaO1vUafFk6ZjcE7DNuZJV/kbv450OL07bOREiW9AIa9YU5; _ga_KH7CX71Y5X=GS1.1.1707512432.3.0.1707512647.0.0.0; uber_auth_tkt=4f02281fb77889dd70827446e72c53b409535afe6f04a2465267263447b2fe12d841fa13c11165ce7294d6aabfcf642f18761b9f934e52972c3712446984a29665c69356YWFjYzk4MThAZ21haWwuY29t!A7f47b3516942805735b71d30590c7a!userid_type:b64unicode; uber_auth_tkt=4f02281fb77889dd70827446e72c53b409535afe6f04a2465267263447b2fe12d841fa13c11165ce7294d6aabfcf642f18761b9f934e52972c3712446984a29665c69356YWFjYzk4MThAZ21haWwuY29t!A7f47b3516942805735b71d30590c7a!userid_type:b64unicode; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Feb+10+2024+00%3A42%3A56+GMT%2B0330+(Iran+Standard+Time)&version=202401.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=6140ce0d-5f43-490a-afcc-537d77783362&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0&AwaitingReconsent=false&geolocation=NL%3BUT; session=WBdXsyfYBzJBi-jMdZKFm2VMuelYvc9bZJr2_zkTK9NwCplHcX2ed-U-85FFToDDMcRxUzBGisj8irrXpJTIfFsxNzA3NTEzMjEyLCAxNzA3NDk5MzIxLjI4Mjc2NjgsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiX2NzcmZ0XyI6ICJlZTU5NTZiODIyMDJmNzljYWY0MTMwZjQwZWMyNWE3MzRlODM3MzIwIiwgImF1dGhfbWV0aG9kIjogImRpbWVuc2lvbnMifV0; session=uJtBq90fb3VkpvCcsftUN1ecXN2M_jcCS-NSepueUQ8oXU3MTPtK6VYoljhfO5MthESsvCTWnT5jmTn94bz0MlsxNzA3NTEzMjcxLCAxNzA3NDczMzk4LjA4NDEwODYsIHsiYXV0aGVudGljYXRpb24iOiBudWxsLCAiX2NzcmZ0XyI6ICIwMjZkZTJmNzY3MWNiOWJmZjg5MWZlMWI4OGE0NWFmOWZhNzI0OTEwIiwgImF1dGhfbWV0aG9kIjogImRpbWVuc2lvbnMifV0',
  'Expires': '0',
  'Pragma': 'no-cache',
  'Referer': 'https://app.dimensions.ai/analytics/publication/source_title/aggregated?or_facet_publication_type=article',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
  'X-CSRF-Token': 'ee5956b82202f79caf4130f40ec25a734e837320',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"headers": [{"id": "name", "label": "Name", "sublabel": null, "actions": []}, {"id": "count", "label": "Publications", "sublabel": "", "actions": [], "sort": {"id": "count", "selected": true}}, {"id": "times_cited_sum", "label": "Citations", "sublabel": "", "actions": [], "sort": null}, {"id": "times_cited_avg", "label": "Citations", "sublabel": "mean", "actions": [], "sort": null}], "results": [{"id": "jour.1016355", "name": {"label": "ChemInform", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1016355"}}, "count": {"label": 792569, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1016355"}}, "times_cited_sum": {"label": 50343.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 0.06351875988084318, "format": "float", "navigation": null}}, {"id": "jour.1077219", "name": {"label": "The Lancet", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1077219"}}, "count": {"label": 456995, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1077219"}}, "times_cited_sum": {"label": 7873610.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 17.229094410223308, "format": "float", "navigation": null}}, {"id": "jour.1017377", "name": {"label": "The BMJ", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1017377"}}, "count": {"label": 440837, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1017377"}}, "times_cited_sum": {"label": 3884268.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 8.811120663646655, "format": "float", "navigation": null}}, {"id": "jour.1018957", "name": {"label": "Nature", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1018957"}}, "count": {"label": 431314, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1018957"}}, "times_cited_sum": {"label": 21197080.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 49.14535581965807, "format": "float", "navigation": null}}, {"id": "jour.1346339", "name": {"label": "Science", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1346339"}}, "count": {"label": 370342, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1346339"}}, "times_cited_sum": {"label": 18153579.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 49.01841811082729, "format": "float", "navigation": null}}, {"id": "jour.1001816", "name": {"label": "Notes and Queries", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1001816"}}, "count": {"label": 337289, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1001816"}}, "times_cited_sum": {"label": 20046.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 0.05943271200661747, "format": "float", "navigation": null}}, {"id": "jour.1081531", "name": {"label": "JAMA", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1081531"}}, "count": {"label": 330175, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1081531"}}, "times_cited_sum": {"label": 5438684.0, "format": "decimal", "navigation": null}, "times_cited_avg": {"label": 16.47212538805179, "format": "float", "navigation": null}}, {"id": "jour.1037553", "name": {"label": "PLOS ONE", "sublabel": null, "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1037553"}}, "count": {"label": 293316, "format": "decimal", "navigation": {"path": "/discover/publication?and_facet_source_title=jour.1037553"}}, "times_cited_sum": {"label": 8760719.0, "format": "decimal", "navig ...

# %%
import pandas as pd 
sources = list()
num = 0

# %%
sources = list()
res = response.json().get('results')
for i in res:
    var_dict = {'id':i.get('id'), 'name':i.get('name').get('label')}
    sources.append(var_dict)

# %%
while True:
   try:
      # print(num)
      # num = num + 1
      response = requests.request("GET", url, headers=headers, data=payload)
      print(response.status_code)
      data = response.json()
      res = data.get('results')

      for i in res:
         sum_count = sum_count+ i.get('count').get('label')

      np = data['navigation']['data_json']
      url = f"https://app.dimensions.ai{np}&or_facet_publication_type=article&or_facet_year=2023&and_facet_for=80024&viz-st:aggr=mean"
      print(url)
   except Exception as err:
        print(err)
        break
# Out:
# 200
# https://app.dimensions.ai/viz/data/publication/for/aggregated-citations.json?np=rox-CJSIA5SvlpaH7c6nM0HISXWzDXLeECIsH4VDtQat0jC21FzoknEybYAN&or_facet_publication_type=article&or_facet_year=2023&and_facet_for=80024&viz-st:aggr=mean
# 200
# https://app.dimensions.ai/viz/data/publication/for/aggregated-citations.json?np=garIo9Wi9mq-d_i6Y87RrtGuphmqq2xf4gwhHulmzYuOboaak3GXcT14w7yg&or_facet_publication_type=article&or_facet_year=2023&and_facet_for=80024&viz-st:aggr=mean
# 200
# https://app.dimensions.ai/viz/data/publication/for/aggregated-citations.json?np=S86p1FK0_Y9keUBMjN_TXIE8HH9GLtnBIRH88CJvgRwkOBPPpcQgrim4D7PI&or_facet_publication_type=article&or_facet_year=2023&and_facet_for=80024&viz-st:aggr=mean
# 200
# 'NoneType' object is not subscriptable

# %%
sources = list()
while True:
   try:
      response = requests.request("GET", url, headers=headers, data=payload)
      data = response.json()
      res = data.get('results')
      for i in res:
         var_dict = {'id':i.get('id'), 'name':i.get('name').get('label')}
         sources.append(var_dict)

      np = data['navigation']['data_json']
      url = f"https://app.dimensions.ai{np}&or_facet_publication_type=article&viz-st:aggr=mean"
   except Exception as err:
        print(err)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 4
#       2 while True:
#       3    try:
# ----> 4       response = requests.request("GET", url, headers=headers, data=payload)
#       5       data = response.json()
#       6       res = data.get('results')
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:779, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     777 if self.proxy is not None and http_tunnel_required and conn.is_closed:
#     778     try:
# --> 779         self._prepare_proxy(conn)
#     780     except (BaseSSLError, OSError, SocketTimeout) as e:
#     781         self._raise_timeout(
#     782             err=e, url=self.proxy.url, timeout_value=conn.timeout
#     783         )
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1048, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1040     tunnel_scheme = "http"
#    1042 conn.set_tunnel(
#    1043     scheme=tunnel_scheme,
#    1044     host=self._tunnel_host,
#    1045     port=self.port,
#    1046     headers=self.proxy_headers,
#    1047 )
# -> 1048 conn.connect()
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:653, in HTTPSConnection.connect(self)
#     650 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#     673 # Forwarding proxies can never have a verified target since
#     674 # the proxy is the one doing the verification. Should instead
#     675 # use a CONNECT tunnel in order to verify the target.
#     676 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     803     if is_ipaddress(normalized):
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#     820     if assert_fingerprint:
#
# File c:\Users\snappshop\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:440, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     438 if ca_certs or ca_cert_dir or ca_cert_data:
#     439     try:
# --> 440         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     441     except OSError as e:
#     442         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
url
# Out:
# 'https://app.dimensions.ai/viz/data/publication/source_title/aggregated-citations.json?np=x-S-rLDnN8gwb_q8qHx9V08Onxs8jgtITofbIy6GPHQhZTBYShdJyjzXG3f3GnM%3D&or_facet_publication_type=article&viz-st:aggr=mean'

# %%
pd.DataFrame(sources).to_csv('source_1.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.DataFrame(sources).to_csv('source_1.csv',index=False)
#
# NameError: name 'pd' is not defined

# %%
pd.DataFrame(sources)
# Out:
#                 id                                          name
# 0     jour.1016355                                    ChemInform
# 1     jour.1077219                                    The Lancet
# 2     jour.1017377                                       The BMJ
# 3     jour.1018957                                        Nature
# 4     jour.1346339                                       Science
# ...            ...                                           ...
# 3735  jour.1097894                       Reproductive Toxicology
# 3736  jour.1059074  Chinese Journal of Obstetrics and Gynecology
# 3737  jour.1297366                                   The Surgeon
# 3738  jour.1296822                                      繊維製品消費科学
# 3739  jour.1122661  Journal of Dispersion Science and Technology
#
# [3740 rows x 2 columns]

# %%
sources
# Out:
# [{'id': 'jour.1016355', 'name': 'ChemInform'},
#  {'id': 'jour.1077219', 'name': 'The Lancet'},
#  {'id': 'jour.1017377', 'name': 'The BMJ'},
#  {'id': 'jour.1018957', 'name': 'Nature'},
#  {'id': 'jour.1346339', 'name': 'Science'},
#  {'id': 'jour.1001816', 'name': 'Notes and Queries'},
#  {'id': 'jour.1081531', 'name': 'JAMA'},
#  {'id': 'jour.1037553', 'name': 'PLOS ONE'},
#  {'id': 'jour.1092067', 'name': 'Reactions Weekly'},
#  {'id': 'jour.1320488', 'name': 'Physical Review B'},
#  {'id': 'jour.1081898', 'name': 'Journal of the American Chemical Society'},
#  {'id': 'jour.1077138', 'name': 'Journal of Biological Chemistry'},
#  {'id': 'jour.1045337', 'name': 'Scientific Reports'},
#  {'id': 'jour.1128789', 'name': 'Choice'},
#  {'id': 'jour.1043366', 'name': 'Journal of Physics Conference Series'},
#  {'id': 'jour.1014075', 'name': 'New England Journal of Medicine'},
#  {'id': 'jour.1018656', 'name': 'Scientific American'},
#  {'id': 'jour.1085025', 'name': 'Blood'},
#  {'id': 'jour.1081893',
#   'name': 'The Journal of the Acoustical Society of America'},
#  {'id': 'jour.1082971',
#   'name': 'Proceedings of the National Academy of Sciences of the United States of America'},
#  {'id': 'jour.1297502', 'name': 'Chemical & Engineering News'},
#  {'id': 'jour.1312191', 'name': 'Journal of Clinical Oncology'},
#  {'id': 'jour.1077136', 'name': 'Journal of Applied Physics'},
#  {'id': 'jour.1319913', 'name': 'Cancer Research'},
#  {'id': 'jour.1017429', 'name': 'The FASEB Journal'},
#  {'id': 'jour.1017736', 'name': 'The Journal of Chemical Physics'},
#  {'id': 'jour.1017675', 'name': 'Investigative Urology'},
#  {'id': 'jour.1017616', 'name': 'Gastroenterology'},
#  {'id': 'jour.1358828', 'name': 'The Medical Journal of Australia'},
#  {'id': 'jour.1018277', 'name': 'Physical Review Letters'},
#  {'id': 'jour.1125016', 'name': 'Applied Physics Letters'},
#  {'id': 'jour.1008386', 'name': 'The American Historical Review'},
#  {'id': 'jour.1345331', 'name': 'Analytical Chemistry'},
#  {'id': 'jour.1134140', 'name': 'The Astrophysical Journal'},
#  {'id': 'jour.1023179', 'name': 'Angewandte Chemie'},
#  {'id': 'jour.1136876', 'name': 'Applied Mechanics and Materials'},
#  {'id': 'jour.1093746',
#   'name': 'Journal of the American College of Cardiology'},
#  {'id': 'jour.1320496', 'name': 'Physical Review D'},
#  {'id': 'jour.1137264',
#   'name': 'IOP Conference Series Earth and Environmental Science'},
#  {'id': 'jour.1358693', 'name': 'Analytical and Bioanalytical Chemistry'},
#  {'id': 'jour.1010438', 'name': 'Nursing Standard'},
#  {'id': 'jour.1077001', 'name': 'Tetrahedron Letters'},
#  {'id': 'jour.1137008',
#   'name': 'IOP Conference Series Materials Science and Engineering'},
#  {'id': 'jour.1017359', 'name': 'American Journal of Nursing'},
#  {'id': 'jour.1077134', 'name': 'The Journal of Immunology'},
#  {'id': 'jour.1430674', 'name': 'Biochimica et Biophysica Acta'},
#  {'id': 'jour.1312044',
#   'name': 'Biochemical and Biophysical Research Communications'},
#  {'id': 'jour.1077200', 'name': 'The Journal of Organic Chemistry'},
#  {'id': 'jour.1017044', 'name': 'Angewandte Chemie International Edition'},
#  {'id': 'jour.1011551', 'name': 'Medicine & Science in Sports & Exercise'},
#  {'id': 'jour.1017013',
#   'name': 'American Journal of Obstetrics and Gynecology'},
#  {'id': 'jour.1053349', 'name': 'Physical Review A'},
#  {'id': 'jour.1297159', 'name': 'Chemical Communications'},
#  {'id': 'jour.1001454', 'name': 'DMW - Deutsche Medizinische Wochenschrift'},
#  {'id': 'jour.1137398', 'name': 'IFAC-PapersOnLine'},
#  {'id': 'jour.1387079', 'name': 'ECS Meeting Abstracts'},
#  {'id': 'jour.1084664', 'name': 'Inpharma Weekly'},
#  {'id': 'jour.1022968',
#   'name': 'Monthly Notices of the Royal Astronomical Society'},
#  {'id': 'jour.1018238', 'name': 'Neurology'},
#  {'id': 'jour.1312079', 'name': 'Journal of Geophysical Research'},
#  {'id': 'jour.1012865', 'name': 'CHEST Journal'},
#  {'id': 'jour.1028874', 'name': 'International Journal of Molecular Sciences'},
#  {'id': 'jour.1312269', 'name': 'Japanese Journal of Applied Physics'},
#  {'id': 'jour.1009570', 'name': 'Circulation'},
#  {'id': 'jour.1412991', 'name': 'The American Journal of Gastroenterology'},
#  {'id': 'jour.1449362', 'name': 'CABI Compendium'},
#  {'id': 'jour.1085033',
#   'name': 'International Journal of Radiation Oncology • Biology • Physics'},
#  {'id': 'jour.1046556', 'name': 'Sustainability'},
#  {'id': 'jour.1345339', 'name': 'Plastic & Reconstructive Surgery'},
#  {'id': 'jour.1050631', 'name': 'IEEE Access'},
#  {'id': 'jour.1117575', 'name': 'Brain Research'},
#  {'id': 'jour.1023084', 'name': 'Acta Horticulturae'},
#  {'id': 'jour.1297379', 'name': 'MRS Advances'},
#  {'id': 'jour.1017078', 'name': 'Biophysical Journal'},
#  {'id': 'jour.1041821', 'name': 'Journal of Alloys and Compounds'},
#  {'id': 'jour.1046724', 'name': 'RSC Advances'},
#  {'id': 'jour.1015499', 'name': 'The Science of The Total Environment'},
#  {'id': 'jour.1358263', 'name': 'Inorganic Chemistry'},
#  {'id': 'jour.1412796', 'name': 'Biochemistry'},
#  {'id': 'jour.1003421',
#   'name': 'The American Journal of the Medical Sciences'},
#  {'id': 'jour.1020835', 'name': 'Value in Health'},
#  {'id': 'jour.1399520', 'name': 'Annals of the New York Academy of Sciences'},
#  {'id': 'jour.1312290', 'name': 'Physical Review E'},
#  {'id': 'jour.1101155', 'name': 'Annals of Internal Medicine'},
#  {'id': 'jour.1126459', 'name': 'Chemical Physics Letters'},
#  {'id': 'jour.1017022', 'name': 'American Journal of Physiology'},
#  {'id': 'jour.1094748', 'name': 'Physics Letters B'},
#  {'id': 'jour.1312267', 'name': 'Journal of the Royal Society of Medicine'},
#  {'id': 'jour.1034947',
#   'name': 'International Journal of Environmental Research and Public Health'},
#  {'id': 'jour.1043282', 'name': 'Nature Communications'},
#  {'id': 'jour.1076908', 'name': 'Biochemical Journal'},
#  {'id': 'jour.1033312', 'name': 'Sensors'},
#  {'id': 'jour.1430192', 'name': 'Applied Sciences'},
#  {'id': 'jour.1019308', 'name': 'Canadian Medical Association Journal'},
#  {'id': 'jour.1135048', 'name': 'Journal of Applied Polymer Science'},
#  {'id': 'jour.1038686', 'name': 'Applied Surface Science'},
#  {'id': 'jour.1327376', 'name': 'Applied Optics'},
#  {'id': 'jour.1008793', 'name': 'Transplantation'},
#  {'id': 'jour.1091325', 'name': 'European Heart Journal'},
#  {'id': 'jour.1018340', 'name': 'Radiology'},
#  {'id': 'jour.1030495', 'name': 'Optics Express'},
#  {'id': 'jour.1312252', 'name': 'European Journal of Inorganic Chemistry'},
#  {'id': 'jour.1017874', 'name': 'Pediatrics'},
#  {'id': 'jour.1017430', 'name': 'Fertility and Sterility'},
#  {'id': 'jour.1357503',
#   'name': 'International Journal of Rock Mechanics and Mining Sciences'},
#  {'id': 'jour.1358132', 'name': 'British Journal of Surgery'},
#  {'id': 'jour.1313621', 'name': 'Journal of the Franklin Institute'},
#  {'id': 'jour.1055294', 'name': 'Anesthesiology'},
#  {'id': 'jour.1297987',
#   'name': 'Journal of the Society of Mechanical Engineers'},
#  {'id': 'jour.1055081', 'name': 'Journal of Allergy and Clinical Immunology'},
#  {'id': 'jour.1011235', 'name': 'Science News'},
#  {'id': 'jour.1009938', 'name': 'FEBS Letters'},
#  {'id': 'jour.1042151', 'name': 'AIP Conference Proceedings'},
#  {'id': 'jour.1077137', 'name': 'Journal of Bacteriology'},
#  {'id': 'jour.1100417', 'name': 'Annals of Oncology'},
#  {'id': 'jour.1018818', 'name': 'Review of Scientific Instruments'},
#  {'id': 'jour.1016994', 'name': 'Bioscience Biotechnology and Biochemistry'},
#  {'id': 'jour.1013348', 'name': 'アレルギー'},
#  {'id': 'jour.1047717', 'name': 'Cureus'},
#  {'id': 'jour.1012116', 'name': 'Environmental Science and Technology'},
#  {'id': 'jour.1017256', 'name': 'JAMA Internal Medicine'},
#  {'id': 'jour.1082768', 'name': 'Journal of The Electrochemical Society'},
#  {'id': 'jour.1100826', 'name': 'Physical Chemistry Chemical Physics'},
#  {'id': 'jour.1041450', 'name': 'ACS Applied Materials & Interfaces'},
#  {'id': 'jour.1400121', 'name': 'Academy of Management Proceedings'},
#  {'id': 'jour.1126662', 'name': 'Electronics Letters'},
#  {'id': 'jour.1076837', 'name': 'Tetrahedron'},
#  {'id': 'jour.1017681', 'name': 'Journal of Agricultural and Food Chemistry'},
#  {'id': 'jour.1038386', 'name': 'The Journal of Physical Chemistry C'},
#  {'id': 'jour.1126508', 'name': 'Langmuir'},
#  {'id': 'jour.1412803', 'name': 'The American Journal of Cardiology'},
#  {'id': 'jour.1016342', 'name': 'Critical Care Medicine'},
#  {'id': 'jour.1312072', 'name': 'Molecules'},
#  {'id': 'jour.1104846', 'name': 'Journal of Chromatography A'},
#  {'id': 'jour.1018982', 'name': 'Nucleic Acids Research'},
#  {'id': 'jour.1066294', 'name': 'Physics Today'},
#  {'id': 'jour.1031859', 'name': 'Journal of Physics Condensed Matter'},
#  {'id': 'jour.1034467', 'name': "Alzheimer's & Dementia"},
#  {'id': 'jour.1312324', 'name': 'The Journal of Physical Chemistry'},
#  {'id': 'jour.1077139', 'name': 'Journal of Chemical Education'},
#  {'id': 'jour.1097771', 'name': 'Endocrinology'},
#  {'id': 'jour.1002368', 'name': 'The British Journal of Psychiatry'},
#  {'id': 'jour.1312241',
#   'name': 'Nuclear Instruments and Methods in Physics Research Section A Accelerators Spectrometers Detectors and Associated Equipment'},
#  {'id': 'jour.1398054', 'name': 'La Presse Médicale'},
#  {'id': 'jour.1082894', 'name': '日本小児外科学会雑誌'},
#  {'id': 'jour.1008072', 'name': 'Journal of Virology'},
#  {'id': 'jour.1002859', 'name': 'Southern Medical Journal'},
#  {'id': 'jour.1312058', 'name': 'Physics Letters A'},
#  {'id': 'jour.1004415', 'name': 'Veterinary Record'},
#  {'id': 'jour.1095400', 'name': 'Journal of Hepatology'},
#  {'id': 'jour.1312024', 'name': 'Physical Review'},
#  {'id': 'jour.1089909',
#   'name': 'Journal of the American Academy of Dermatology'},
#  {'id': 'jour.1094728', 'name': 'Radiotherapy and Oncology'},
#  {'id': 'jour.1054339', 'name': 'The New Scientist'},
#  {'id': 'jour.1027092', 'name': 'Experimental Biology and Medicine'},
#  {'id': 'jour.1016709', 'name': 'Macromolecules'},
#  {'id': 'jour.1070136', 'name': 'Vacuum'},
#  {'id': 'jour.1017738',
#   'name': 'The Journal of Clinical Endocrinology & Metabolism'},
#  {'id': 'jour.1027733', 'name': 'Dalton Transactions'},
#  {'id': 'jour.1000637', 'name': 'JAMA Dermatology'},
#  {'id': 'jour.1000968', 'name': 'Gastrointestinal Endoscopy'},
#  {'id': 'jour.1141196', 'name': 'E3S Web of Conferences'},
#  {'id': 'jour.1007352', 'name': 'Pediatric Research'},
#  {'id': 'jour.1120274', 'name': 'American Mathematical Monthly'},
#  {'id': 'jour.1031548', 'name': 'The Journal of Physical Chemistry B'},
#  {'id': 'jour.1017226', 'name': 'Annals of the Rheumatic Diseases'},
#  {'id': 'jour.1137514', 'name': 'Energies'},
#  {'id': 'jour.1430810', 'name': 'Journal of Education'},
#  {'id': 'jour.1017023', 'name': 'American Journal of Psychiatry'},
#  {'id': 'jour.1082853', 'name': 'Japanese Journal of Radiological Technology'},
#  {'id': 'jour.1120663', 'name': 'Electrochimica Acta'},
#  {'id': 'jour.1127675', 'name': 'Chemical Engineering Journal'},
#  {'id': 'jour.1017574', 'name': 'Cancer'},
#  {'id': 'jour.1085241', 'name': 'Applied and Environmental Microbiology'},
#  {'id': 'jour.1017754', 'name': 'The Journal of Pediatrics'},
#  {'id': 'jour.1126650', 'name': 'Geophysical Research Letters'},
#  {'id': 'jour.1294974', 'name': 'European Journal of Cancer'},
#  {'id': 'jour.1017014', 'name': 'American Journal of Ophthalmology'},
#  {'id': 'jour.1038953', 'name': 'Journal of Magnetism and Magnetic Materials'},
#  {'id': 'jour.1317459', 'name': 'Books Abroad'},
#  {'id': 'jour.1312031', 'name': 'The Journal of Physiology'},
#  {'id': 'jour.1026093', 'name': 'Astronomy & Astrophysics'},
#  {'id': 'jour.1136878', 'name': 'Fuel and Energy Abstracts'},
#  {'id': 'jour.1057026', 'name': 'The Annals of Thoracic Surgery'},
#  {'id': 'jour.1039417', 'name': 'Thin Solid Films'},
#  {'id': 'jour.1114579', 'name': 'Chemistry - A European Journal'},
#  {'id': 'jour.1026109', 'name': 'International Journal of Hydrogen Energy'},
#  {'id': 'jour.1013475', 'name': 'Transplantation Proceedings'},
#  {'id': 'jour.1015185', 'name': 'Chemosphere'},
#  {'id': 'jour.1026135', 'name': 'IEEE Transactions on Magnetics'},
#  {'id': 'jour.1055662', 'name': 'Anesthesia & Analgesia'},
#  {'id': 'jour.1015476', 'name': 'Archiv der Pharmazie'},
#  {'id': 'jour.1320490', 'name': 'Physical Review C'},
#  {'id': 'jour.1327126',
#   'name': 'Acta Crystallographica Section E: Crystallographic Communications'},
#  {'id': 'jour.1082997', 'name': 'Microscopy and Microanalysis'},
#  {'id': 'jour.1055590', 'name': 'Ugeskrift for Laeger'},
#  {'id': 'jour.1312116', 'name': 'Journal of Materials Science'},
#  {'id': 'jour.1050159', 'name': 'PsycCRITIQUES'},
#  {'id': 'jour.1005567', 'name': 'Journal of Colloid and Interface Science'},
#  {'id': 'jour.1113424',
#   'name': 'Environmental Science and Pollution Research'},
#  {'id': 'jour.1024921', 'name': 'Journal of American History'},
#  {'id': 'jour.1345398', 'name': 'Clinical Neurophysiology'},
#  {'id': 'jour.1044868', 'name': 'Materials'},
#  {'id': 'jour.1121115', 'name': 'Solid State Communications'},
#  {'id': 'jour.1134649', 'name': 'Astronomische Nachrichten'},
#  {'id': 'jour.1017751', 'name': 'The Journal of Nervous and Mental Disease'},
#  {'id': 'jour.1295829', 'name': 'Bulletin des Médecins Suisses'},
#  {'id': 'jour.1091000', 'name': 'Journal of Animal Science'},
#  {'id': 'jour.1007389', 'name': 'Journal of the American College of Surgeons'},
#  {'id': 'jour.1018250', 'name': 'Obstetrics and Gynecology'},
#  {'id': 'jour.1054235', 'name': 'European Journal of Pharmacology'},
#  {'id': 'jour.1019787', 'name': 'Clinical journal of Japan'},
#  {'id': 'jour.1019138', 'name': 'Tidsskrift for Den norske legeforening'},
#  {'id': 'jour.1011527', 'name': 'Journal of Organometallic Chemistry'},
#  {'id': 'jour.1020133', 'name': 'Medical Physics'},
#  {'id': 'jour.1017037', 'name': 'Analytica Chimica Acta'},
#  {'id': 'jour.1136879', 'name': 'Monthly Weather Review'},
#  {'id': 'jour.1052494', 'name': 'Materials Today Proceedings'},
#  {'id': 'jour.1313329',
#   'name': 'Journal of Thoracic and Cardiovascular Surgery'},
#  {'id': 'jour.1087001', 'name': 'Optics Letters'},
#  {'id': 'jour.1121514', 'name': 'Journal of the Physical Society of Japan'},
#  {'id': 'jour.1044598', 'name': 'Frontiers in Psychology'},
#  {'id': 'jour.1087555', 'name': 'Neurosurgery'},
#  {'id': 'jour.1016324',
#   'name': 'Chemischer Informationsdienst Organische Chemie'},
#  {'id': 'jour.1126601', 'name': 'Industrial & Engineering Chemistry Research'},
#  {'id': 'jour.1092210', 'name': 'Journal of Neuroscience'},
#  {'id': 'jour.1051522', 'name': 'Ceramics International'},
#  {'id': 'jour.1052482', 'name': 'Journal of High Energy Physics'},
#  {'id': 'jour.1044002', 'name': 'Journal of Cleaner Production'},
#  {'id': 'jour.1013101', 'name': 'Stroke'},
#  {'id': 'jour.1018190', 'name': 'Nederlands Tijdschrift voor Geneeskunde'},
#  {'id': 'jour.1038065', 'name': 'Materials Science and Engineering A'},
#  {'id': 'jour.1020022', 'name': 'Nursing Times'},
#  {'id': 'jour.1355191', 'name': 'Case Medical Research'},
#  {'id': 'jour.1018528', 'name': 'American Journal of Roentgenology'},
#  {'id': 'jour.1026138', 'name': 'Journal of Crystal Growth'},
#  {'id': 'jour.1017225', 'name': 'Annals of Surgery'},
#  {'id': 'jour.1371252', 'name': 'RöFo'},
#  {'id': 'jour.1057918', 'name': 'Journal of Molecular Medicine'},
#  {'id': 'jour.1077253', 'name': 'Medicine'},
#  {'id': 'jour.1021332', 'name': 'Organic Letters'},
#  {'id': 'jour.1086261', 'name': 'Food Chemistry'},
#  {'id': 'jour.1016325', 'name': 'Nephrology Dialysis Transplantation'},
#  {'id': 'jour.1094093', 'name': 'Journal of Hypertension'},
#  {'id': 'jour.1297407', 'name': 'The FEBS Journal'},
#  {'id': 'jour.1009258', 'name': 'Journal of Molecular Structure'},
#  {'id': 'jour.1312251', 'name': 'The Journal of Physical Chemistry A'},
#  {'id': 'jour.1017010', 'name': 'The American Journal of Surgery'},
#  {'id': 'jour.1084595', 'name': 'British Dental Journal'},
#  {'id': 'jour.1044881',
#   'name': 'Proceedings of the American Mathematical Society'},
#  {'id': 'jour.1082610', 'name': 'Bulletin of the Chemical Society of Japan'},
#  {'id': 'jour.1012038',
#   'name': 'Acta Crystallographica Section A: Foundations and advances'},
#  {'id': 'jour.1412807', 'name': 'Diabetes'},
#  {'id': 'jour.1017004', 'name': 'American Heart Journal'},
#  {'id': 'jour.1045166', 'name': 'Frontiers in Immunology'},
#  {'id': 'jour.1022309', 'name': 'Russian Chemical Bulletin'},
#  {'id': 'jour.1077143', 'name': 'Journal of Dairy Science'},
#  {'id': 'jour.1000902', 'name': 'British Journal of Dermatology'},
#  {'id': 'jour.1084802', 'name': 'Neuroscience Letters'},
#  {'id': 'jour.1017752', 'name': 'Journal of the Neurological Sciences'},
#  {'id': 'jour.1046461', 'name': 'Physica B Condensed Matter'},
#  {'id': 'jour.1121140', 'name': 'Surface Science'},
#  {'id': 'jour.1120988', 'name': 'Optics Communications'},
#  {'id': 'jour.1004292', 'name': 'ファルマシア'},
#  {'id': 'jour.1412088', 'name': 'International Journal of Cardiology'},
#  {'id': 'jour.1358061', 'name': 'Journal of Investigative Dermatology'},
#  {'id': 'jour.1077144', 'name': 'Journal of Economic Entomology'},
#  {'id': 'jour.1000170', 'name': 'Läkartidningen'},
#  {'id': 'jour.1016775', 'name': 'Urology'},
#  {'id': 'jour.1017362', 'name': 'Analyst'},
#  {'id': 'jour.1125574',
#   'name': 'Nuclear Instruments and Methods in Physics Research Section B Beam Interactions with Materials and Atoms'},
#  {'id': 'jour.1036748', 'name': 'European Urology Open Science'},
#  {'id': 'jour.1032373', 'name': 'Zootaxa'},
#  {'id': 'jour.1096341', 'name': 'The Laryngoscope'},
#  {'id': 'jour.1297467',
#   'name': 'Journal of the Academy of Nutrition and Dietetics'},
#  {'id': 'jour.1042608', 'name': 'Materials Letters'},
#  {'id': 'jour.1017275', 'name': 'Arizona Medicine'},
#  {'id': 'jour.1135259', 'name': 'Polymer'},
#  {'id': 'jour.1019235', 'name': 'The Journal of Infectious Diseases'},
#  {'id': 'jour.1024766', 'name': 'International Affairs'},
#  {'id': 'jour.1062267', 'name': 'Journal of Medicinal Chemistry'},
#  {'id': 'jour.1101614', 'name': 'European Psychiatry'},
#  {'id': 'jour.1044923', 'name': 'Fuel'},
#  {'id': 'jour.1049033', 'name': 'physica status solidi (b)'},
#  {'id': 'jour.1006102', 'name': 'Journal of Pediatric Surgery'},
#  {'id': 'jour.1027235', 'name': 'Nuclear Physics A'},
#  {'id': 'jour.1358108', 'name': 'Journal of the National Cancer Institute'},
#  {'id': 'jour.1123255', 'name': 'Polyhedron'},
#  {'id': 'jour.1017915', 'name': 'The Quarterly Review of Biology'},
#  {'id': 'jour.1094744', 'name': 'Journal of Vascular Surgery'},
#  {'id': 'jour.1062083', 'name': 'Journal of Pharmacological Sciences'},
#  {'id': 'jour.1312064', 'name': 'Archives of Biochemistry and Biophysics'},
#  {'id': 'jour.1084797',
#   'name': 'Journal of Physics A: Mathematical and Theoretical'},
#  {'id': 'jour.1047255', 'name': 'JAMA Ophthalmology'},
#  {'id': 'jour.1297422', 'name': 'Journal of Clinical Investigation'},
#  {'id': 'jour.1018314', 'name': 'Plant Physiology'},
#  {'id': 'jour.1412191',
#   'name': 'Journal of Industrial & Engineering Chemistry'},
#  {'id': 'jour.1077105', 'name': 'Journal of Molecular Biology'},
#  {'id': 'jour.1136882', 'name': 'The Modern Language Review'},
#  {'id': 'jour.1008250', 'name': 'Antimicrobial Agents and Chemotherapy'},
#  {'id': 'jour.1295005', 'name': 'Cellular and Molecular Life Sciences'},
#  {'id': 'jour.1312073', 'name': 'American Political Science Review'},
#  {'id': 'jour.1089721', 'name': 'Clinical Infectious Diseases'},
#  {'id': 'jour.1052836', 'name': 'Construction and Building Materials'},
#  {'id': 'jour.1044693', 'name': 'BMJ Open'},
#  {'id': 'jour.1001969', 'name': 'The Hospital and Health Review'},
#  {'id': 'jour.1297394', 'name': 'JAMA Pediatrics'},
#  {'id': 'jour.1009647', 'name': 'Phytochemistry'},
#  {'id': 'jour.1017950', 'name': 'Journal of Applied Physiology'},
#  {'id': 'jour.1017763', 'name': 'Life Sciences'},
#  {'id': 'jour.1006259', 'name': 'The Classical Review'},
#  {'id': 'jour.1042951', 'name': 'Journal of Power Sources'},
#  {'id': 'jour.1030998', 'name': 'Journal of Vision'},
#  {'id': 'jour.1018189', 'name': 'The Science of Nature'},
#  {'id': 'jour.1013611', 'name': 'Infection and Immunity'},
#  {'id': 'jour.1017253', 'name': 'Archives of Disease in Childhood'},
#  {'id': 'jour.1101548', 'name': 'European Neuropsychopharmacology'},
#  {'id': 'jour.1054347', 'name': 'Journal of Physics D'},
#  {'id': 'jour.1041745', 'name': 'Journal of the American Ceramic Society'},
#  {'id': 'jour.1136881', 'name': 'World Literature Today'},
#  {'id': 'jour.1430432', 'name': 'Acta Physica Sinica'},
#  {'id': 'jour.1013420', 'name': 'Atherosclerosis'},
#  {'id': 'jour.1014535', 'name': 'The American Journal of Medicine'},
#  {'id': 'jour.1024367', 'name': 'The English Historical Review'},
#  {'id': 'jour.1016817', 'name': 'World Neurosurgery'},
#  {'id': 'jour.1129018', 'name': 'Advanced Materials'},
#  {'id': 'jour.1034895',
#   'name': 'The Journal of the American Dental Association'},
#  {'id': 'jour.1044458', 'name': 'Frontiers in Microbiology'},
#  {'id': 'jour.1082459',
#   'name': 'The Annals of the American Academy of Political and Social Science'},
#  {'id': 'jour.1004769',
#   'name': 'Zeitschrift für anorganische und allgemeine Chemie'},
#  {'id': 'jour.1313731', 'name': 'American Journal of Health-System Pharmacy'},
#  {'id': 'jour.1082731', 'name': 'Journal of Clinical Microbiology'},
#  {'id': 'jour.1024607', 'name': 'Hispanic American Historical Review'},
#  {'id': 'jour.1017122', 'name': 'Geburtshilfe und Frauenheilkunde'},
#  {'id': 'jour.1017031',
#   'name': 'American Journal of Respiratory and Critical Care Medicine'},
#  {'id': 'jour.1106099', 'name': 'Journal of Hazardous Materials'},
#  {'id': 'jour.1357526',
#   'name': 'physica status solidi (a) – applications and materials science'},
#  {'id': 'jour.1031133', 'name': 'Sensors and Actuators B Chemical'},
#  {'id': 'jour.1017863',
#   'name': 'Oral Surgery Oral Medicine Oral Pathology and Oral Radiology'},
#  {'id': 'jour.1134069',
#   'name': 'Journal of Mathematical Analysis and Applications'},
#  {'id': 'jour.1430766', 'name': 'Remote Sensing'},
#  {'id': 'jour.1327455',
#   'name': 'International Journal of Heat and Mass Transfer'},
#  {'id': 'jour.1222138', 'name': 'The Musical Times'},
#  {'id': 'jour.1090468', 'name': 'Journal of Electroanalytical Chemistry'},
#  {'id': 'jour.1048347', 'name': 'Energy'},
#  {'id': 'jour.1092629', 'name': 'Molecular and Cellular Biology'},
#  {'id': 'jour.1090935', 'name': 'Annals of Emergency Medicine'},
#  {'id': 'jour.1312301', 'name': 'Otolaryngology'},
#  {'id': 'jour.1077023', 'name': 'The Japanese Journal of Urology'},
#  {'id': 'jour.1058040', 'name': 'ビタミン'},
#  {'id': 'jour.1024535', 'name': 'French Studies'},
#  {'id': 'jour.1399993',
#   'name': 'Journal of the American Veterinary Medical Association'},
#  {'id': 'jour.1017867', 'name': 'Orvosi Hetilap'},
#  {'id': 'jour.1076998', 'name': 'Talanta'},
#  {'id': 'jour.1023201', 'name': 'The Astronomical Journal'},
#  {'id': 'jour.1314528', 'name': 'Research Society and Development'},
#  {'id': 'jour.1007365', 'name': 'Biochemical Pharmacology'},
#  {'id': 'jour.1043519', 'name': 'Procedia - Social and Behavioral Sciences'},
#  {'id': 'jour.1018283', 'name': 'Poultry Science'},
#  {'id': 'jour.1083357', 'name': 'Biochemical Society Transactions'},
#  {'id': 'jour.1126625', 'name': 'Journal of Nuclear Materials'},
#  {'id': 'jour.1134078',
#   'name': 'Physica A Statistical Mechanics and its Applications'},
#  {'id': 'jour.1357590', 'name': 'Chinese Science Bulletin (Chinese Version)'},
#  {'id': 'jour.1119830', 'name': 'Inorganica Chimica Acta'},
#  {'id': 'jour.1358156', 'name': 'International Journal of Cancer'},
#  {'id': 'jour.1312263', 'name': 'Physics of Plasmas'},
#  {'id': 'jour.1327790', 'name': 'IEEE Transactions on Nuclear Science'},
#  {'id': 'jour.1017007', 'name': 'American Journal of Clinical Pathology'},
#  {'id': 'jour.1295034', 'name': 'Advanced Synthesis & Catalysis'},
#  {'id': 'jour.1017847',
#   'name': 'Journal of Pharmacology and Experimental Therapeutics'},
#  {'id': 'jour.1101293', 'name': 'Bioorganic & Medicinal Chemistry Letters'},
#  {'id': 'jour.1121330', 'name': 'Chemie Ingenieur Technik'},
#  {'id': 'jour.1125125', 'name': 'Organometallics'},
#  {'id': 'jour.1287925', 'name': 'Zeitschrift für Physikalische Chemie'},
#  {'id': 'jour.1097778', 'name': 'South African Medical Journal'},
#  {'id': 'jour.1055099', 'name': 'American Anthropologist'},
#  {'id': 'jour.1056952', 'name': 'Annalen der Physik'},
#  {'id': 'jour.1017316',
#   'name': 'Bulletin of Experimental Biology and Medicine'},
#  {'id': 'jour.1077197', 'name': 'Journal of Neurochemistry'},
#  {'id': 'jour.1039980', 'name': 'Microelectronics Reliability'},
#  {'id': 'jour.1048290', 'name': 'Journal of Clinical Medicine'},
#  {'id': 'jour.1090368',
#   'name': 'International Journal of Biological Macromolecules'},
#  {'id': 'jour.1017038', 'name': 'Analytical Biochemistry'},
#  {'id': 'jour.1133055', 'name': 'Bioresource Technology'},
#  {'id': 'jour.1062273',
#   'name': 'Journal of Neurology Neurosurgery & Psychiatry'},
#  {'id': 'jour.1044217', 'name': 'Procedia Engineering'},
#  {'id': 'jour.1126748', 'name': 'HortScience'},
#  {'id': 'jour.1127662', 'name': 'Chemical Engineering Science'},
#  {'id': 'jour.1044186', 'name': 'Journal of Non-Crystalline Solids'},
#  {'id': 'jour.1043122', 'name': 'BMJ Case Reports'},
#  {'id': 'jour.1101367', 'name': 'Ultrasound in Obstetrics and Gynecology'},
#  {'id': 'jour.1059210', 'name': 'Clinical Chemistry'},
#  {'id': 'jour.1021622', 'name': 'MMW - Fortschritte der Medizin'},
#  {'id': 'jour.1026143', 'name': 'Journal of Fluid Mechanics'},
#  {'id': 'jour.1047259', 'name': 'JAMA Surgery'},
#  {'id': 'jour.1312121', 'name': 'Nuclear Physics B'},
#  {'id': 'jour.1094724', 'name': 'Vaccine'},
#  {'id': 'jour.1120277', 'name': 'Water Science & Technology'},
#  {'id': 'jour.1007212', 'name': 'Clinical Orthopaedics and Related Research®'},
#  {'id': 'jour.1017902', 'name': 'Psychological Reports'},
#  {'id': 'jour.1019990', 'name': 'IEEE Transactions on Electron Devices'},
#  {'id': 'jour.1345497',
#   'name': 'Spectrochimica Acta Part A Molecular and Biomolecular Spectroscopy'},
#  {'id': 'jour.1358114', 'name': 'British Journal of Radiology'},
#  {'id': 'jour.1009866', 'name': 'British Journal of Pharmacology'},
#  {'id': 'jour.1137312', 'name': 'MATEC Web of Conferences'},
#  {'id': 'jour.1018068', 'name': 'Chemical and Pharmaceutical Bulletin'},
#  {'id': 'jour.1030524', 'name': 'Endocrine Abstracts'},
#  {'id': 'jour.1007902', 'name': 'Virology'},
#  {'id': 'jour.1015179', 'name': 'Chemistry Letters'},
#  {'id': 'jour.1061674', 'name': 'The Indian Medical Gazette'},
#  {'id': 'jour.1042723', 'name': 'Nutrients'},
#  {'id': 'jour.1083512', 'name': 'Colloid and Polymer Science'},
#  {'id': 'jour.1013016', 'name': 'Journal of Oral and Maxillofacial Surgery'},
#  {'id': 'jour.1017306', 'name': 'British Journal of Anaesthesia'},
#  {'id': 'jour.1017735', 'name': 'Journal of Cell Biology'},
#  {'id': 'jour.1023000', 'name': 'Ornithology'},
#  {'id': 'jour.1297148', 'name': 'The Journal of Laryngology and Otology'},
#  {'id': 'jour.1087073', 'name': 'Toxicology Letters'},
#  {'id': 'jour.1044557', 'name': 'Surface and Coatings Technology'},
#  {'id': 'jour.1017081', 'name': 'Heart'},
#  {'id': 'jour.1017032', 'name': 'Anaesthesia'},
#  {'id': 'jour.1312111', 'name': 'Physica C Superconductivity'},
#  {'id': 'jour.1136883', 'name': 'AIAA Journal'},
#  {'id': 'jour.1051415',
#   'name': 'The London Edinburgh and Dublin Philosophical Magazine and Journal of Science'},
#  {'id': 'jour.1022875', 'name': 'Proceedings of the IEEE'},
#  {'id': 'jour.1093917', 'name': 'Hepatology'},
#  {'id': 'jour.1017854', 'name': 'Journal of Trauma and Acute Care Surgery'},
#  {'id': 'jour.1026179', 'name': 'Eos'},
#  {'id': 'jour.1016940', 'name': 'Acta Ophthalmologica'},
#  {'id': 'jour.1399744', 'name': 'Biological Psychiatry'},
#  {'id': 'jour.1093601',
#   'name': 'The Journal of Heart and Lung Transplantation'},
#  {'id': 'jour.1111912', 'name': 'PharmacoEconomics & Outcomes News'},
#  {'id': 'jour.1139455', 'name': 'The Mathematical Gazette'},
#  {'id': 'jour.1371202', 'name': "Langenbeck's Archives of Surgery"},
#  {'id': 'jour.1399687', 'name': 'Nordisk Medicin'},
#  {'id': 'jour.1104711', 'name': '気管支学'},
#  {'id': 'jour.1038900', 'name': 'Journal of Visualized Experiments'},
#  {'id': 'jour.1062309', 'name': 'Journal of Sound and Vibration'},
#  {'id': 'jour.1017748', 'name': 'Academic Medicine'},
#  {'id': 'jour.1092108', 'name': 'La Revue de Médecine Interne'},
#  {'id': 'jour.1047721', 'name': 'Journal of Materials Chemistry A'},
#  {'id': 'jour.1284558', 'name': 'Innovation in Aging'},
#  {'id': 'jour.1016762',
#   'name': 'Journal of Physics B Atomic Molecular and Optical Physics'},
#  {'id': 'jour.1017082', 'name': 'British Journal of Cancer'},
#  {'id': 'jour.1077125', 'name': 'Gut'},
#  {'id': 'jour.1085139', 'name': 'Neuroscience'},
#  {'id': 'jour.1043645', 'name': 'Oncotarget'},
#  {'id': 'jour.1045668', 'name': 'Frontiers in Plant Science'},
#  {'id': 'jour.1087256', 'name': 'Modern Healthcare'},
#  {'id': 'jour.1043163', 'name': 'Cancers'},
#  {'id': 'jour.1017919', 'name': 'JAMA Otolaryngology - Head & Neck Surgery'},
#  {'id': 'jour.1033315', 'name': 'Carbon'},
#  {'id': 'jour.1002308', 'name': 'Journal of Bone and Joint Surgery'},
#  {'id': 'jour.1002327', 'name': 'Journal of Food Science'},
#  {'id': 'jour.1047896', 'name': 'BioMed Research International'},
#  {'id': 'jour.1013212', 'name': 'Journal de Chirurgie Viscérale'},
#  {'id': 'jour.1017308', 'name': 'British Journal of Haematology'},
#  {'id': 'jour.1032248',
#   'name': 'Journal of the American Pharmacists Association'},
#  {'id': 'jour.1290619',
#   'name': 'International Journal for Research in Applied Science and Engineering Technology'},
#  {'id': 'jour.1000463', 'name': 'Journal of Natural History'},
#  {'id': 'jour.1013927', 'name': 'Journal of Neurosurgery'},
#  {'id': 'jour.1018164', 'name': 'Minerva Medica'},
#  {'id': 'jour.1011929',
#   'name': 'International Journal of Gynecology & Obstetrics'},
#  {'id': 'jour.1103053', 'name': 'NeuroImage'},
#  {'id': 'jour.1297370', 'name': 'Rheumatology'},
#  {'id': 'jour.1057222',
#   'name': 'Archives of Physical Medicine and Rehabilitation'},
#  {'id': 'jour.1312167', 'name': 'European Food Research and Technology'},
#  {'id': 'jour.1036468', 'name': 'Synfacts'},
#  {'id': 'jour.1045696', 'name': 'Frontiers in Oncology'},
#  {'id': 'jour.1284594',
#   'name': 'IEEE Transactions on Antennas and Propagation'},
#  {'id': 'jour.1032876', 'name': 'Advanced Functional Materials'},
#  {'id': 'jour.1018580', 'name': 'Journal of Nutrition'},
#  {'id': 'jour.1017006', 'name': 'American Journal of Botany'},
#  {'id': 'jour.1020141', 'name': 'Contemporary Sociology A Journal of Reviews'},
#  {'id': 'jour.1007697', 'name': 'Water Research'},
#  {'id': 'jour.1005222',
#   'name': 'Pflügers Archiv - European Journal of Physiology'},
#  {'id': 'jour.1055382', 'name': 'Clinica Chimica Acta'},
#  {'id': 'jour.1077126', 'name': 'Journal of Experimental Medicine'},
#  {'id': 'jour.1086756', 'name': 'Gene'},
#  {'id': 'jour.1043968', 'name': 'Procedia Computer Science'},
#  {'id': 'jour.1133657', 'name': 'Journal of Mathematical Physics'},
#  {'id': 'jour.1412985', 'name': 'American Journal of Clinical Nutrition'},
#  {'id': 'jour.1056671', 'name': 'American Journal of Physics'},
#  {'id': 'jour.1297988',
#   'name': 'The Proceedings of JSME annual Conference on Robotics and Mechatronics (Robomec)'},
#  {'id': 'jour.1043671',
#   'name': 'The International Journal of Advanced Manufacturing Technology'},
#  {'id': 'jour.1297203', 'name': 'Heliyon'},
#  {'id': 'jour.1018525', 'name': 'Digestive Diseases and Sciences'},
#  {'id': 'jour.1016705', 'name': 'Gynecologic Oncology'},
#  {'id': 'jour.1412780', 'name': 'Journal of Pharmaceutical Sciences'},
#  {'id': 'jour.1312164', 'name': 'Journal of the Chemical Society'},
#  {'id': 'jour.1040436',
#   'name': 'Transportation Research Record Journal of the Transportation Research Board'},
#  {'id': 'jour.1055128', 'name': 'Physica Scripta'},
#  {'id': 'jour.1297378',
#   'name': 'BJOG An International Journal of Obstetrics & Gynaecology'},
#  {'id': 'jour.1135213',
#   'name': 'Colloids and Surfaces A Physicochemical and Engineering Aspects'},
#  {'id': 'jour.1013002', 'name': 'American Journal of Sociology'},
#  {'id': 'jour.1006767', 'name': 'Planta Medica'},
#  {'id': 'jour.1017832', 'name': 'Journal of Surgical Research'},
#  {'id': 'jour.1049082', 'name': 'ECS Transactions'},
#  {'id': 'jour.1005576', 'name': 'Speculum'},
#  {'id': 'jour.1127852', 'name': 'Chemistry of Materials'},
#  {'id': 'jour.1102176', 'name': 'European Journal of Public Health'},
#  {'id': 'jour.1103922', 'name': 'BJU International'},
#  {'id': 'jour.1004765', 'name': 'Zeitschrift für Gastroenterologie'},
#  {'id': 'jour.1430627',
#   'name': 'International Journal of Computer Applications'},
#  {'id': 'jour.1000068', 'name': 'Acta Paediatrica'},
#  {'id': 'jour.1019591', 'name': 'Surgery'},
#  {'id': 'jour.1113735', 'name': 'Clinical Cancer Research'},
#  {'id': 'jour.1005434', 'name': 'Psychiatric Services'},
#  {'id': 'jour.1036793', 'name': 'Military Medicine'},
#  {'id': 'jour.1043052', 'name': 'Nanoscale'},
#  {'id': 'jour.1083693', 'name': 'Journal of Japan Surgical Association'},
#  {'id': 'jour.1017385', 'name': 'Canadian Journal of Chemistry'},
#  {'id': 'jour.1086047', 'name': '心身医学'},
#  {'id': 'jour.1018270', 'name': 'Perceptual and Motor Skills'},
#  {'id': 'jour.1092307', 'name': 'Anticancer Research'},
#  {'id': 'jour.1019815', 'name': 'British Journal of Ophthalmology'},
#  {'id': 'jour.1017910', 'name': 'Public Health'},
#  {'id': 'jour.1368419', 'name': '日本物理学会誌'},
#  {'id': 'jour.1050465', 'name': 'Open Forum Infectious Diseases'},
#  {'id': 'jour.1024954', 'name': 'BMC Public Health'},
#  {'id': 'jour.1026754', 'name': 'The Expository Times'},
#  {'id': 'jour.1094634',
#   'name': 'Journal of Radioanalytical and Nuclear Chemistry'},
#  {'id': 'jour.1017523', 'name': 'Experimental Cell Research'},
#  {'id': 'jour.1019114', 'name': 'Cell'},
#  {'id': 'jour.1136884', 'name': 'Review & Expositor'},
#  {'id': 'jour.1136825',
#   'name': 'Journal of Materials Science: Materials in Electronics'},
#  {'id': 'jour.1086359',
#   'name': 'Investigative Ophthalmology & Visual Science'},
#  {'id': 'jour.1314538', 'name': 'Brazilian Journal of Development'},
#  {'id': 'jour.1077111', 'name': 'Helvetica Chimica Acta'},
#  {'id': 'jour.1005853', 'name': 'Circulation Research'},
#  {'id': 'jour.1007934', 'name': 'Plant Disease'},
#  {'id': 'jour.1320599', 'name': 'American Journal of International Law'},
#  {'id': 'jour.1122988', 'name': 'Advances in Space Research'},
#  {'id': 'jour.1136891', 'name': 'Anthropology News'},
#  {'id': 'jour.1123356',
#   'name': 'IEEE Transactions on Microwave Theory and Techniques'},
#  {'id': 'jour.1013019', 'name': 'Postgraduate Medical Journal'},
#  {'id': 'jour.1097289', 'name': 'Free Radical Biology and Medicine'},
#  {'id': 'jour.1319923', 'name': 'Physics of Fluids'},
#  {'id': 'jour.1024532', 'name': 'Geographical Journal'},
#  {'id': 'jour.1126648', 'name': 'Agronomy Journal'},
#  {'id': 'jour.1014189', 'name': 'Marine Pollution Bulletin'},
#  {'id': 'jour.1019194', 'name': 'Yakugaku Zasshi'},
#  {'id': 'jour.1093316',
#   'name': 'Journal of Pediatric Gastroenterology and Nutrition'},
#  {'id': 'jour.1087199', 'name': 'New Journal of Chemistry'},
#  {'id': 'jour.1101321', 'name': 'Current Biology'},
#  {'id': 'jour.1120732', 'name': 'Geochimica et Cosmochimica Acta'},
#  {'id': 'jour.1319882', 'name': 'Journal of Internal Medicine'},
#  {'id': 'jour.1358136',
#   'name': 'Acta Crystallographica Section C: Structural Chemistry'},
#  {'id': 'jour.1044360', 'name': 'Polymers'},
#  {'id': 'jour.1051546',
#   'name': 'Zeitschrift für Kristallographie - Crystalline Materials'},
#  {'id': 'jour.1297428', 'name': 'Journal of Molecular Liquids'},
#  {'id': 'jour.1312129', 'name': 'American Journal of Public Health'},
#  {'id': 'jour.1097727', 'name': 'Lung Cancer'},
#  {'id': 'jour.1017857', 'name': 'Medicina Clínica'},
#  {'id': 'jour.1126746', 'name': 'Journal of Hydrology'},
#  {'id': 'jour.1098046', 'name': 'Environmental Pollution'},
#  {'id': 'jour.1096829', 'name': 'Human Reproduction'},
#  {'id': 'jour.1017021',
#   'name': 'American Journal of Tropical Medicine and Hygiene'},
#  {'id': 'jour.1018204', 'name': 'Obstetrical & Gynecological Survey'},
#  {'id': 'jour.1084146', 'name': 'Applied Mathematics and Computation'},
#  {'id': 'jour.1294862', 'name': 'Journal of Thermal Analysis and Calorimetry'},
#  {'id': 'jour.1019100', 'name': 'Khirurgiya Zhurnal im N I Pirogova'},
#  {'id': 'jour.1087742', 'name': 'International Journal of Pharmaceutics'},
#  {'id': 'jour.1294976',
#   'name': 'European Journal of Lipid Science and Technology'},
#  {'id': 'jour.1398516', 'name': 'Water'},
#  {'id': 'jour.1023183', 'name': 'Crop Science'},
#  {'id': 'jour.1014308',
#   'name': 'Journal of Molecular and Cellular Cardiology'},
#  {'id': 'jour.1129971', 'name': 'EPL (Europhysics Letters)'},
#  {'id': 'jour.1001534', 'name': 'Scottish medical and surgical journal.'},
#  {'id': 'jour.1093138', 'name': 'Food and Chemical Toxicology'},
#  {'id': 'jour.1130647', 'name': 'Aquaculture'},
#  {'id': 'jour.1085727', 'name': 'Spine'},
#  {'id': 'jour.1026120', 'name': 'Geological Magazine'},
#  {'id': 'jour.1021029', 'name': 'Neuro-Oncology'},
#  {'id': 'jour.1006098', 'name': 'Journal of Cell Science'},
#  {'id': 'jour.1036857', 'name': 'Journal of Thoracic Oncology'},
#  {'id': 'jour.1023171', 'name': 'Hydrobiologia'},
#  {'id': 'jour.1049106',
#   'name': 'International Journal of Current Microbiology and Applied Sciences'},
#  {'id': 'jour.1047857',
#   'name': 'Transactions of the American Mathematical Society'},
#  {'id': 'jour.1035078', 'name': 'Nanotechnology'},
#  {'id': 'jour.1010158', 'name': 'Journal of Biomechanics'},
#  {'id': 'jour.1068714', 'name': 'Social Forces'},
#  {'id': 'jour.1337575',
#   'name': 'The Proceedings of the Annual Convention of the Japanese Psychological Association'},
#  {'id': 'jour.1081904', 'name': 'Journal of the American Geriatrics Society'},
#  {'id': 'jour.1082725', 'name': 'American Water Works Association'},
#  {'id': 'jour.1018657', 'name': 'Swiss Medical Weekly'},
#  {'id': 'jour.1007263', 'name': 'ChemPlusChem'},
#  {'id': 'jour.1017753', 'name': 'Journal of Neurophysiology'},
#  {'id': 'jour.1005854', 'name': 'Hypertension'},
#  {'id': 'jour.1043435', 'name': 'Materials Chemistry and Physics'},
#  {'id': 'jour.1005600', 'name': 'Ecology'},
#  {'id': 'jour.1027009', 'name': 'European Journal of Operational Research'},
#  {'id': 'jour.1157000', 'name': 'ACS Omega'},
#  {'id': 'jour.1013500', 'name': 'Journal of Experimental Biology'},
#  {'id': 'jour.1031925', 'name': 'Environmental Health Perspectives'},
#  {'id': 'jour.1123672', 'name': 'The Journal of Asian Studies'},
#  {'id': 'jour.1136476', 'name': 'Measurement Techniques'},
#  {'id': 'jour.1430836',
#   'name': 'Journal of Biological Research - Bollettino della Società Italiana di Biologia Sperimentale'},
#  {'id': 'jour.1019032', 'name': 'Вестник хирургии имени И. И. Грекова'},
#  {'id': 'jour.1358829', 'name': 'Postgraduate Medicine'},
#  {'id': 'jour.1026246', 'name': 'Energy & Fuels'},
#  {'id': 'jour.1085288', 'name': 'Journal of Membrane Science'},
#  {'id': 'jour.1017365', 'name': 'Archives of Gynecology and Obstetrics'},
#  {'id': 'jour.1042305',
#   'name': 'IEEE Transactions on Applied Superconductivity'},
#  {'id': 'jour.1022207', 'name': 'Applied Physics A'},
#  {'id': 'jour.1029687',
#   'name': 'Journal d imagerie diagnostique et interventionnelle'},
#  {'id': 'jour.1412101', 'name': 'European Journal of Endocrinology'},
#  {'id': 'jour.1044455', 'name': 'Frontiers in Pharmacology'},
#  {'id': 'jour.1312319', 'name': 'Acta Radiologica'},
#  {'id': 'jour.1029519', 'name': 'Applied Energy'},
#  {'id': 'jour.1018318', 'name': 'Praxis'},
#  {'id': 'jour.1050331', 'name': 'Applied Thermal Engineering'},
#  {'id': 'jour.1100250',
#   'name': 'Journal of Polymer Science Part A Polymer Chemistry'},
#  {'id': 'jour.1097543', 'name': 'Oncogene'},
#  {'id': 'jour.1102090',
#   'name': 'Journal of Vascular and Interventional Radiology'},
#  {'id': 'jour.1018186',
#   'name': 'Mutation Research/Fundamental and Molecular Mechanisms of Mutagenesis'},
#  {'id': 'jour.1015319', 'name': 'Kidney International'},
#  {'id': 'jour.1398497', 'name': 'Developmental Biology'},
#  {'id': 'jour.1019093', 'name': 'Hygiene and Sanitation'},
#  {'id': 'jour.1017079', 'name': 'Biull Eksp Biol Med'},
#  {'id': 'jour.1020753', 'name': 'World Journal of Gastroenterology'},
#  {'id': 'jour.1128045', 'name': 'Expert Systems with Applications'},
#  {'id': 'jour.1082734',
#   'name': 'Journal of the American Academy of Child & Adolescent Psychiatry'},
#  {'id': 'jour.1136993', 'name': 'EPJ Web of Conferences'},
#  {'id': 'jour.1033500', 'name': 'IEEE Transactions on Automatic Control'},
#  {'id': 'jour.1017354', 'name': 'European Journal of Pediatrics'},
#  {'id': 'jour.1076868', 'name': '日本消化器病学会雑誌'},
#  {'id': 'jour.1094102', 'name': 'Carbohydrate Polymers'},
#  {'id': 'jour.1026864', 'name': 'School Science and Mathematics'},
#  {'id': 'jour.1038301', 'name': 'Journal of Solid State Chemistry'},
#  {'id': 'jour.1034222', 'name': 'Ophthalmology'},
#  {'id': 'jour.1297328', 'name': 'Journal of Nanoscience and Nanotechnology'},
#  {'id': 'jour.1000340',
#   'name': 'Journal of Physical Education Recreation & Dance'},
#  {'id': 'jour.1312178', 'name': 'FEMS Microbiology Letters'},
#  {'id': 'jour.1077211', 'name': 'Clinical Medicine (Russian Journal)'},
#  {'id': 'jour.1088823', 'name': 'Cancer & chemotherapy'},
#  {'id': 'jour.1017622', 'name': 'Genetics'},
#  {'id': 'jour.1017015',
#   'name': 'American Journal of Orthodontics and Dentofacial Orthopedics'},
#  {'id': 'jour.1009619',
#   'name': 'Journal of the American Statistical Association'},
#  {'id': 'jour.1017016', 'name': 'American Journal Of Pathology'},
#  {'id': 'jour.1038917', 'name': 'ACS Nano'},
#  {'id': 'jour.1028316', 'name': 'Nano Letters'},
#  {'id': 'jour.1142012', 'name': 'Journal of Forestry'},
#  {'id': 'jour.1038872', 'name': 'Wear'},
#  {'id': 'jour.1021346', 'name': 'Molecular Therapy'},
#  {'id': 'jour.1084019', 'name': 'Synthesis'},
#  {'id': 'jour.1033572', 'name': 'IEEE Sensors Journal'},
#  {'id': 'jour.1136922', 'name': 'Theology'},
#  {'id': 'jour.1136980', 'name': 'Mathematical Problems in Engineering'},
#  {'id': 'jour.1053654',
#   'name': 'Bulletin of the American Meteorological Society'},
#  {'id': 'jour.1044093', 'name': 'Energy Procedia'},
#  {'id': 'jour.1070920',
#   'name': 'Zhurnal nevrologii i psikhiatrii im S S Korsakova'},
#  {'id': 'jour.1000356', 'name': 'Physical Therapy'},
#  {'id': 'jour.1097961', 'name': 'Schizophrenia Research'},
#  {'id': 'jour.1007922', 'name': 'Seibutsu Butsuri'},
#  {'id': 'jour.1077000', 'name': 'Terapevticheskii arkhiv'},
#  {'id': 'jour.1092720', 'name': 'American Journal of Kidney Diseases'},
#  {'id': 'jour.1055181', 'name': 'Measurement Science and Technology'},
#  {'id': 'jour.1313831', 'name': 'Zeitschrift für Physik A Hadrons and nuclei'},
#  {'id': 'jour.1103715', 'name': 'Diabetes Care'},
#  {'id': 'jour.1297371', 'name': 'ChemPhysChem'},
#  {'id': 'jour.1016843', 'name': 'Clinical Science'},
#  {'id': 'jour.1084666', 'name': 'Journal of Antimicrobial Chemotherapy'},
#  {'id': 'jour.1019190', 'name': "Likars'ka Sprava"},
#  {'id': 'jour.1077189', 'name': 'Isis'},
#  {'id': 'jour.1017743', 'name': 'Microbiology'},
#  {'id': 'jour.1033557', 'name': 'IEEE Photonics Technology Letters'},
#  {'id': 'jour.1118025', 'name': 'European Journal of Organic Chemistry'},
#  {'id': 'jour.1016944', 'name': 'Acta Oto-Laryngologica'},
#  {'id': 'jour.1082983', 'name': 'Proceedings of the Royal Society A'},
#  {'id': 'jour.1011872', 'name': 'Biology of Reproduction'},
#  {'id': 'jour.1076870', 'name': 'The American Naturalist'},
#  {'id': 'jour.1048491', 'name': 'Renewable Energy'},
#  {'id': 'jour.1076990', 'name': 'Nursing'},
#  {'id': 'jour.1371223',
#   'name': 'Journal of the Chemical Society Perkin Transactions 1'},
#  {'id': 'jour.1018801', 'name': 'The Journal of Comparative Neurology'},
#  {'id': 'jour.1081604', 'name': 'Water Resources Research'},
#  {'id': 'jour.1312259', 'name': 'Proceedings of the Royal Society B'},
#  {'id': 'jour.1017071', 'name': 'Australian Veterinary Journal'},
#  {'id': 'jour.1013320', 'name': 'Optometry and Vision Science'},
#  {'id': 'jour.1018211', 'name': 'Optik'},
#  {'id': 'jour.1017828',
#   'name': 'Journal of the Science of Food and Agriculture'},
#  {'id': 'jour.1019991',
#   'name': 'IEEE Transactions on Instrumentation and Measurement'},
#  {'id': 'jour.1017682', 'name': 'Journal of Catalysis'},
#  {'id': 'jour.1023705', 'name': 'Heart Lung and Circulation'},
#  {'id': 'jour.1017953', 'name': 'Journal of Clinical Pathology'},
#  {'id': 'jour.1004761', 'name': 'European Archives of Oto-Rhino-Laryngology'},
#  {'id': 'jour.1034711', 'name': 'Small'},
#  {'id': 'jour.1136889', 'name': 'Modern Language Journal'},
#  {'id': 'jour.1065152', 'name': 'Nihon Naika Gakkai Zasshi'},
#  {'id': 'jour.1358127', 'name': 'La Revue du Praticien'},
#  {'id': 'jour.1093956', 'name': 'Social Science & Medicine'},
#  {'id': 'jour.1059303', 'name': 'ANZ Journal of Surgery'},
#  {'id': 'jour.1090493', 'name': 'American Journal of Epidemiology'},
#  {'id': 'jour.1092363', 'name': 'Macromolecular Chemistry and Physics'},
#  {'id': 'jour.1070586', 'name': 'Wiener klinische Wochenschrift'},
#  {'id': 'jour.1126767', 'name': 'Soil Science Society of America Journal'},
#  {'id': 'jour.1297345', 'name': 'National Medical Journal of China'},
#  {'id': 'jour.1023204',
#   'name': 'Publications of the Astronomical Society of the Pacific'},
#  {'id': 'jour.1128071', 'name': 'Thermochimica Acta'},
#  {'id': 'jour.1138740', 'name': 'Nuclear and Particle Physics Proceedings'},
#  {'id': 'jour.1122763', 'name': 'Optical Engineering'},
#  {'id': 'jour.1086213', 'name': 'Annales de Dermatologie et de Vénéréologie'},
#  {'id': 'jour.1018187', 'name': 'Mycologia'},
#  {'id': 'jour.1008498', 'name': 'AORN Journal'},
#  {'id': 'jour.1430170', 'name': 'Chinese Physics B'},
#  {'id': 'jour.1020052', 'name': 'Survey of Anesthesiology'},
#  {'id': 'jour.1093201', 'name': 'The EMBO Journal'},
#  {'id': 'jour.1038545', 'name': 'Synthetic Metals'},
#  {'id': 'jour.1017634', 'name': 'Hospitals & Health Networks'},
#  {'id': 'jour.1083533', 'name': 'Applied Microbiology and Biotechnology'},
#  {'id': 'jour.1430171', 'name': 'Journal of Environmental Management'},
#  {'id': 'jour.1019675', 'name': 'Cell and Tissue Research'},
#  {'id': 'jour.1009265', 'name': 'Journal of Physics and Chemistry of Solids'},
#  {'id': 'jour.1017952', 'name': 'The Journal of Biochemistry'},
#  {'id': 'jour.1002359', 'name': 'Klinische Monatsblätter für Augenheilkunde'},
#  {'id': 'jour.1082739',
#   'name': "Journal of the American Oil Chemists' Society"},
#  {'id': 'jour.1412111', 'name': 'Arthritis & Rheumatism'},
#  {'id': 'jour.1126647', 'name': 'New Phytologist'},
#  {'id': 'jour.1026116', 'name': 'Earth and Planetary Science Letters'},
#  {'id': 'jour.1017849', 'name': 'Journal of Prosthetic Dentistry'},
#  {'id': 'jour.1033607', 'name': 'Journal of Lightwave Technology'},
#  {'id': 'jour.1005598', 'name': 'Carbohydrate Research'},
#  {'id': 'jour.1017690', 'name': 'American Journal of Veterinary Research'},
#  {'id': 'jour.1084729', 'name': 'Chinese Medical Journal'},
#  {'id': 'jour.1017521', 'name': 'Evolution'},
#  {'id': 'jour.1313722',
#   'name': 'Proceedings of the Human Factors and Ergonomics Society Annual Meeting'},
#  {'id': 'jour.1017255', 'name': 'JAMA Neurology'},
#  {'id': 'jour.1117766', 'name': 'Critical Care'},
#  {'id': 'jour.1005966', 'name': 'Journal of Cellular Physiology'},
#  {'id': 'jour.1097145', 'name': 'Biomaterials'},
#  {'id': 'jour.1132096', 'name': 'Atmospheric Environment'},
#  {'id': 'jour.1034700', 'name': 'Journal of Minimally Invasive Gynecology'},
#  {'id': 'jour.1031384', 'name': 'Organic & Biomolecular Chemistry'},
#  {'id': 'jour.1297376', 'name': 'Digestive and Liver Disease'},
#  {'id': 'jour.1006657', 'name': 'The American Biology Teacher'},
#  {'id': 'jour.1128607', 'name': 'Neurocomputing'},
#  {'id': 'jour.1012593', 'name': 'Population'},
#  {'id': 'jour.1136898', 'name': 'Journal of Algebra'},
#  {'id': 'jour.1021358', 'name': 'Biologie Aujourd hui'},
#  {'id': 'jour.1041817', 'name': 'Microwave and Optical Technology Letters'},
#  {'id': 'jour.1345383', 'name': 'Bioinformatics'},
#  {'id': 'jour.1159373',
#   'name': 'Symposium - International Astronomical Union'},
#  {'id': 'jour.1018133', 'name': "Justus Liebig's Annalen der Chemie"},
#  {'id': 'jour.1294863',
#   'name': 'Comparative Biochemistry and Physiology Part A Molecular & Integrative Physiology'},
# ...
#  {'id': 'jour.1033615',
#   'name': 'IEEE Transactions on Geoscience and Remote Sensing'},
#  {'id': 'jour.1009651', 'name': 'Physiology & Behavior'},
#  {'id': 'jour.1019594', 'name': 'Thorax'},
#  {'id': 'jour.1095819', 'name': 'American Journal of Hypertension'},
#  {'id': 'jour.1120918', 'name': 'Molecular Physics'},
#  {'id': 'jour.1001631',
#   'name': 'Journal of the Royal Anthropological Institute'},
#  {'id': 'jour.1091987', 'name': 'Peptides'},
#  {'id': 'jour.1017398', 'name': 'Chemische Berichte'},
#  {'id': 'jour.1015404',
#   'name': "Naunyn-Schmiedeberg's Archives of Pharmacology"},
#  {'id': 'jour.1371653', 'name': 'Biomedicine & Pharmacotherapy'},
#  {'id': 'jour.1121212', 'name': 'IEEE Transactions on Signal Processing'},
#  {'id': 'jour.1358106', 'name': 'Journal of Pharmacy and Pharmacology'},
#  {'id': 'jour.1042424', 'name': 'The Economic Journal'},
#  {'id': 'jour.1081605', 'name': 'The Journal of Rheumatology'},
#  {'id': 'jour.1017030', 'name': 'The American Surgeon'},
#  {'id': 'jour.1028084', 'name': 'AAPG Bulletin'},
#  {'id': 'jour.1015410', 'name': 'Thrombosis Research'},
#  {'id': 'jour.1136895', 'name': 'Journal of Geography (Chigaku Zasshi)'},
#  {'id': 'jour.1083384', 'name': 'Revista Clínica Española'},
#  {'id': 'jour.1062233', 'name': 'Journal of Chemical & Engineering Data'},
#  {'id': 'jour.1136516', 'name': 'Journal of Mathematical Sciences'},
#  {'id': 'jour.1094972', 'name': 'European Journal of Anaesthesiology'},
#  {'id': 'jour.1034742', 'name': 'Clinical Nutrition'},
#  {'id': 'jour.1398026', 'name': 'IEEE Transactions on Communications'},
#  {'id': 'jour.1055602', 'name': 'Toxicon'},
#  {'id': 'jour.1136292', 'name': 'Metallurgical and Materials Transactions A'},
#  {'id': 'jour.1312130',
#   'name': 'American Journal of Public Health and the Nations Health'},
#  {'id': 'jour.1039813', 'name': 'Acta Materialia'},
#  {'id': 'jour.1358264', 'name': 'Chemical Physics'},
#  {'id': 'jour.1122034', 'name': 'Current History'},
#  {'id': 'jour.1087597', 'name': 'Journal of Parasitology'},
#  {'id': 'jour.1374205', 'name': 'Separation and Purification Technology'},
#  {'id': 'jour.1127266', 'name': 'Journal of Computational Physics'},
#  {'id': 'jour.1136897', 'name': 'Metal Powder Report'},
#  {'id': 'jour.1136939',
#   'name': 'Berichte der Bunsengesellschaft für physikalische Chemie'},
#  {'id': 'jour.1027463', 'name': 'American Journal of Agricultural Economics'},
#  {'id': 'jour.1357482', 'name': 'Journal of the Royal Asiatic Society'},
#  {'id': 'jour.1126575', 'name': 'Plant and Soil'},
#  {'id': 'jour.1131466', 'name': 'Powder Technology'},
#  {'id': 'jour.1123338', 'name': 'AIChE Journal'},
#  {'id': 'jour.1412199', 'name': 'American medical press'},
#  {'id': 'jour.1312349',
#   'name': 'Journal of Vacuum Science & Technology B Nanotechnology and Microelectronics Materials Processing Measurement and Phenomena'},
#  {'id': 'jour.1103682', 'name': 'Osteoarthritis and Cartilage'},
#  {'id': 'jour.1026094', 'name': 'Astrophysics and Space Science'},
#  {'id': 'jour.1170511',
#   'name': 'Proceedings of the Water Environment Federation'},
#  {'id': 'jour.1044869', 'name': 'Multimedia Tools and Applications'},
#  {'id': 'jour.1054393', 'name': 'Archives of Dermatological Research'},
#  {'id': 'jour.1085774', 'name': 'Clinical Nuclear Medicine'},
#  {'id': 'jour.1044397', 'name': 'Desalination and Water Treatment'},
#  {'id': 'jour.1297463', 'name': 'Applied Radiation and Isotopes'},
#  {'id': 'jour.1047841', 'name': 'Energy Conversion and Management'},
#  {'id': 'jour.1105545', 'name': 'Annals of Surgical Oncology'},
#  {'id': 'jour.1124767', 'name': 'IEEE Transactions on Information Theory'},
#  {'id': 'jour.1294853',
#   'name': 'International Journal of Systematic and Evolutionary Microbiology'},
#  {'id': 'jour.1412139', 'name': 'Transplantation and Cellular Therapy'},
#  {'id': 'jour.1015307', 'name': 'Public Health Reports'},
#  {'id': 'jour.1312309', 'name': 'The Bone & Joint Journal'},
#  {'id': 'jour.1085446', 'name': 'Thrombosis and Haemostasis'},
#  {'id': 'jour.1012680', 'name': 'Injury'},
#  {'id': 'jour.1100486', 'name': 'Journal of Dental Research'},
#  {'id': 'jour.1285865', 'name': 'Jibi inkōka rinshō. Hosatsu'},
#  {'id': 'jour.1004928', 'name': 'Harefuah'},
#  {'id': 'jour.1033601', 'name': 'IEEE Transactions on Industrial Electronics'},
#  {'id': 'jour.1068988',
#   'name': 'Transactions of the Royal Society of Tropical Medicine and Hygiene'},
#  {'id': 'jour.1297507', 'name': 'International Journal of Clinical Practice'},
#  {'id': 'jour.1102097', 'name': 'Synlett'},
#  {'id': 'jour.1358069', 'name': 'Medizinische Klinik'},
#  {'id': 'jour.1136893', 'name': 'Metal Finishing'},
#  {'id': 'jour.1076964', 'name': '臨床血液'},
#  {'id': 'jour.1138784', 'name': 'Tetsu-to-Hagane'},
#  {'id': 'jour.1136892', 'name': 'The Journal of Theological Studies'},
#  {'id': 'jour.1086127', 'name': 'Annals of Otology Rhinology & Laryngology'},
#  {'id': 'jour.1018807', 'name': 'Mayo Clinic Proceedings'},
#  {'id': 'jour.1136900', 'name': 'Chinese Physics Letters'},
#  {'id': 'jour.1001058', 'name': 'Casopís lékar̆ů c̆eských'},
#  {'id': 'jour.1115751',
#   'name': 'International Journal of Infectious Diseases'},
#  {'id': 'jour.1024161', 'name': 'Annales Histoire Sciences Sociales'},
#  {'id': 'jour.1048545', 'name': 'Nanomaterials'},
#  {'id': 'jour.1430778', 'name': 'International Journal of Advanced Research'},
#  {'id': 'jour.1020804', 'name': 'EP Europace'},
#  {'id': 'jour.1345172', 'name': 'Electronics'},
#  {'id': 'jour.1016717', 'name': 'Revue des Maladies Respiratoires'},
#  {'id': 'jour.1017846', 'name': 'Klinicheskaia khirurgiia'},
#  {'id': 'jour.1024188',
#   'name': 'Bulletin of the School of Oriental and African Studies'},
#  {'id': 'jour.1312062', 'name': 'Journal of chromatography'},
#  {'id': 'jour.1126669', 'name': 'Journal of Experimental Botany'},
#  {'id': 'jour.1380500',
#   'name': 'Progress of Theoretical and Experimental Physics'},
#  {'id': 'jour.1381434', 'name': 'Mathematics'},
#  {'id': 'jour.1022987', 'name': 'Plant Systematics and Evolution'},
#  {'id': 'jour.1115214', 'name': 'Nature Biotechnology'},
#  {'id': 'jour.1054998', 'name': 'European Journal of Immunology'},
#  {'id': 'jour.1032544', 'name': 'Materials Research Bulletin'},
#  {'id': 'jour.1345587', 'name': 'Monatshefte für Chemie - Chemical Monthly'},
#  {'id': 'jour.1089762', 'name': 'Journal of Affective Disorders'},
#  {'id': 'jour.1082682', 'name': 'Доклады Академии Наук'},
#  {'id': 'jour.1012223', 'name': 'Endoscopy'},
#  {'id': 'jour.1086362', 'name': 'Michigan Law Review'},
#  {'id': 'jour.1290483', 'name': 'C&EN Global Enterprise'},
#  {'id': 'jour.1030151', 'name': 'Forest Ecology and Management'},
#  {'id': 'jour.1095411', 'name': 'Bone'},
#  {'id': 'jour.1089348', 'name': 'Journal of Ethnopharmacology'},
#  {'id': 'jour.1076961', 'name': 'Revue Neurologique'},
#  {'id': 'jour.1312379', 'name': 'Zeitschrift für Naturforschung B'},
#  {'id': 'jour.1106235', 'name': 'Virchows Archiv'},
#  {'id': 'jour.1136911', 'name': 'Music Educators Journal'},
#  {'id': 'jour.1033589', 'name': 'IEEE Transactions on Vehicular Technology'},
#  {'id': 'jour.1018310', 'name': 'Physics in Medicine and Biology'},
#  {'id': 'jour.1358101',
#   'name': "Graefe's Archive for Clinical and Experimental Ophthalmology"},
#  {'id': 'jour.1126577', 'name': 'Marine Ecology Progress Series'},
#  {'id': 'jour.1084657', 'name': 'Heterocycles'},
#  {'id': 'jour.1093226', 'name': 'The Pediatric Infectious Disease Journal'},
#  {'id': 'jour.1113451', 'name': 'Journal of Cardiac Failure'},
#  {'id': 'jour.1033676', 'name': 'Werkstoffe und Korrosion'},
#  {'id': 'jour.1124926', 'name': 'Synthetic Communications'},
#  {'id': 'jour.1091687', 'name': 'Food Research International'},
#  {'id': 'jour.1136913', 'name': 'Physics World'},
#  {'id': 'jour.1098220', 'name': 'Surgical Endoscopy'},
#  {'id': 'jour.1017219', 'name': 'Annals of Allergy Asthma & Immunology'},
#  {'id': 'jour.1134073',
#   'name': 'Journal of Vacuum Science & Technology A Vacuum Surfaces and Films'},
#  {'id': 'jour.1294876', 'name': 'Clinical Radiology'},
#  {'id': 'jour.1313351', 'name': 'Transfusion'},
#  {'id': 'jour.1015743',
#   'name': 'International Journal of Oral and Maxillofacial Surgery'},
#  {'id': 'jour.1069813', 'name': 'Pneumologie'},
#  {'id': 'jour.1007277', 'name': 'Journal of General Virology'},
#  {'id': 'jour.1006675', 'name': 'Desalination'},
#  {'id': 'jour.1368407', 'name': '素粒子論研究'},
#  {'id': 'jour.1042541', 'name': 'JOM'},
#  {'id': 'jour.1137017',
#   'name': 'PMLA/Publications of the Modern Language Association of America'},
#  {'id': 'jour.1103049', 'name': 'Journal of AOAC International'},
#  {'id': 'jour.1086361', 'name': 'The Journal of Higher Education'},
#  {'id': 'jour.1017978', 'name': 'Die Medizinische Welt'},
#  {'id': 'jour.1095417', 'name': 'European Journal of Surgical Oncology'},
#  {'id': 'jour.1120691', 'name': 'European Polymer Journal'},
#  {'id': 'jour.1371982', 'name': 'Polski Tygodnik Lekarski'},
#  {'id': 'jour.1104990', 'name': 'Bioorganic & Medicinal Chemistry'},
#  {'id': 'jour.1134009',
#   'name': 'Bulletin of the American Mathematical Society'},
#  {'id': 'jour.1019908', 'name': 'Theriogenology'},
#  {'id': 'jour.1006533', 'name': 'Renaissance Quarterly'},
#  {'id': 'jour.1030487', 'name': 'Computational and Theoretical Chemistry'},
#  {'id': 'jour.1013703', 'name': 'Internal Medicine'},
#  {'id': 'jour.1084078', 'name': 'Pain'},
#  {'id': 'jour.1086165', 'name': 'Journal of Cataract & Refractive Surgery'},
#  {'id': 'jour.1137016', 'name': 'Engineering Structures'},
#  {'id': 'jour.1312325', 'name': 'Journal of Chromatography B'},
#  {'id': 'jour.1017782',
#   'name': 'European Journal of Obstetrics & Gynecology and Reproductive Biology'},
#  {'id': 'jour.1048005', 'name': 'Composite Structures'},
#  {'id': 'jour.1019889',
#   'name': 'Zentralblatt für Chirurgie - Zeitschrift für Allgemeine Viszeral- Thorax- und Gefäßchirurgie'},
#  {'id': 'jour.1082406', 'name': 'Dermatologic Surgery'},
#  {'id': 'jour.1043911', 'name': 'Discrete Mathematics'},
#  {'id': 'jour.1096849', 'name': 'Development'},
#  {'id': 'jour.1038302', 'name': 'Journal of Materials Processing Technology'},
#  {'id': 'jour.1014183',
#   'name': 'The Journal of Steroid Biochemistry and Molecular Biology'},
#  {'id': 'jour.1044459', 'name': 'Frontiers in Physiology'},
#  {'id': 'jour.1032615',
#   'name': 'The Philosophical Magazine A Journal of Theoretical Experimental and Applied Physics'},
#  {'id': 'jour.1136530', 'name': 'Mathematical Notes'},
#  {'id': 'jour.1017834', 'name': 'Journal of Theoretical Biology'},
#  {'id': 'jour.1002332', 'name': 'Journal of Heterocyclic Chemistry'},
#  {'id': 'jour.1136915', 'name': 'Nuclear Engineering and Design'},
#  {'id': 'jour.1136925',
#   'name': 'Proceedings of the International Astronomical Union'},
#  {'id': 'jour.1136887', 'name': 'PeerJ'},
#  {'id': 'jour.1429545', 'name': 'Chemistry of Heterocyclic Compounds'},
#  {'id': 'jour.1007998', 'name': 'International Journal of Dermatology'},
#  {'id': 'jour.1012078', 'name': 'Annals of Pharmacotherapy'},
#  {'id': 'jour.1001475', 'name': 'Developmental Medicine & Child Neurology'},
#  {'id': 'jour.1413054', 'name': 'BJPsych Bulletin'},
#  {'id': 'jour.1022283', 'name': 'Arthropod Management Tests'},
#  {'id': 'jour.1012712', 'name': 'Psychiatric News'},
#  {'id': 'jour.1103093',
#   'name': 'Journal of the European Academy of Dermatology and Venereology'},
#  {'id': 'jour.1017739', 'name': 'Journal of Endocrinology'},
#  {'id': 'jour.1094447', 'name': 'Biotechnology Advances'},
#  {'id': 'jour.1312114', 'name': 'Journal of Materials Chemistry C'},
#  {'id': 'jour.1297497',
#   'name': 'Journal of Plastic Reconstructive & Aesthetic Surgery'},
#  {'id': 'jour.1092701', 'name': 'Radiation Protection Dosimetry'},
#  {'id': 'jour.1067654', 'name': 'Revue Internationale de la Croix-Rouge'},
#  {'id': 'jour.1132648', 'name': 'Journal of Materials Chemistry'},
#  {'id': 'jour.1022076', 'name': 'Hepato Pancreato Biliary'},
#  {'id': 'jour.1018722', 'name': 'Medical Journal of the Russian Federation'},
#  {'id': 'jour.1136910', 'name': 'The Physics Teacher'},
#  {'id': 'jour.1136902',
#   'name': 'TRANSACTIONS OF THE JAPAN SOCIETY OF MECHANICAL ENGINEERS Series C'},
#  {'id': 'jour.1081617', 'name': 'Biotechnology and Bioengineering'},
#  {'id': 'jour.1099625', 'name': 'China Journal of Chinese Materia Medica'},
#  {'id': 'jour.1025498', 'name': 'Political Science Quarterly'},
#  {'id': 'jour.1100063', 'name': 'Biosensors and Bioelectronics'},
#  {'id': 'jour.1295844', 'name': 'Botany Letters'},
#  {'id': 'jour.1023206', 'name': 'The Journal of Modern History'},
#  {'id': 'jour.1412171', 'name': "Journal Français d'Ophtalmologie"},
#  {'id': 'jour.1088701', 'name': 'Behavioral and Brain Sciences'},
#  {'id': 'jour.1327448', 'name': 'Frontiers in Neuroscience'},
#  {'id': 'jour.1289733', 'name': 'Nippon Suisan Gakkaishi'},
#  {'id': 'jour.1024327', 'name': 'Church History'},
#  {'id': 'jour.1313824', 'name': 'Russian Physics Journal'},
#  {'id': 'jour.1135790', 'name': 'International Journal of Quantum Chemistry'},
#  {'id': 'jour.1052511', 'name': 'Solar Energy'},
#  {'id': 'jour.1030485', 'name': 'Physiologia Plantarum'},
#  {'id': 'jour.1051269', 'name': 'Quantum Electronics'},
#  {'id': 'jour.1087747', 'name': 'Journal of the Operational Research Society'},
#  {'id': 'jour.1017424', 'name': 'Diseases of the Colon & Rectum'},
#  {'id': 'jour.1084784', 'name': 'Cancer Letters'},
#  {'id': 'jour.1031080', 'name': 'IEEE Transactions on Plasma Science'},
#  {'id': 'jour.1039135', 'name': "Journal of Crohn's and Colitis"},
#  {'id': 'jour.1009554', 'name': 'Environmental Research'},
#  {'id': 'jour.1033540', 'name': '日本土壌肥料学雑誌'},
#  {'id': 'jour.1023790', 'name': 'BMC Genomics'},
#  {'id': 'jour.1313647',
#   'name': 'Journal of Cancer Research and Clinical Oncology'},
#  {'id': 'jour.1017311', 'name': 'British Journal Of Nutrition'},
#  {'id': 'jour.1019541', 'name': 'Toxicology and Applied Pharmacology'},
#  {'id': 'jour.1136213', 'name': 'Journal of Electronic Materials'},
#  {'id': 'jour.1033560', 'name': 'IEEE Transactions on Power Electronics'},
#  {'id': 'jour.1013562', 'name': 'Gynecologic and Obstetric Investigation'},
#  {'id': 'jour.1039310', 'name': 'Linear Algebra and its Applications'},
#  {'id': 'jour.1100952',
#   'name': 'Arteriosclerosis Thrombosis and Vascular Biology'},
#  {'id': 'jour.1008276', 'name': 'Annales d Endocrinologie'},
#  {'id': 'jour.1136946', 'name': "Bulletin of the Center for Children's Books"},
#  {'id': 'jour.1358075', 'name': 'Anaesthesia Critical Care & Pain Medicine'},
#  {'id': 'jour.1097884', 'name': 'European Respiratory Journal'},
#  {'id': 'jour.1025189', 'name': 'Music and Letters'},
#  {'id': 'jour.1017305', 'name': 'Brain'},
#  {'id': 'jour.1094260', 'name': 'The American Journal of Emergency Medicine'},
#  {'id': 'jour.1016811', 'name': 'Pharmacology Biochemistry and Behavior'},
#  {'id': 'jour.1312338', 'name': 'MMW Münchener Medizinische Wochenschrift'},
#  {'id': 'jour.1013276', 'name': 'The Canadian Entomologist'},
#  {'id': 'jour.1054035', 'name': 'Planta'},
#  {'id': 'jour.1046517', 'name': 'eLife'},
#  {'id': 'jour.1017997', 'name': 'Animal Behaviour'},
#  {'id': 'jour.1100506', 'name': 'Journal of Craniofacial Surgery'},
#  {'id': 'jour.1297380', 'name': 'Molecular Genetics and Genomics'},
#  {'id': 'jour.1024632', 'name': 'BMC Cancer'},
#  {'id': 'jour.1020764', 'name': 'The Yale Law Journal'},
#  {'id': 'jour.1319807', 'name': 'Circulation Journal'},
#  {'id': 'jour.1095684', 'name': 'Environmental Monitoring and Assessment'},
#  {'id': 'jour.1137131', 'name': 'Ocean Engineering'},
#  {'id': 'jour.1040786', 'name': 'Journal of Clinical and Diagnostic Research'},
#  {'id': 'jour.1123393',
#   'name': 'Canadian Journal of Fisheries and Aquatic Sciences'},
#  {'id': 'jour.1439140', 'name': 'Electrical Engineering'},
#  {'id': 'jour.1005581', 'name': 'Experimental Brain Research'},
#  {'id': 'jour.1018837', 'name': 'The Pharmaceutical Journal'},
#  {'id': 'jour.1018975', 'name': 'Ultrasound in Medicine & Biology'},
#  {'id': 'jour.1017724', 'name': 'The Gerontologist'},
#  {'id': 'jour.1297403',
#   'name': 'The European Physical Journal Special Topics'},
#  {'id': 'jour.1297989', 'name': 'The proceedings of the JSME annual meeting'},
#  ...]
